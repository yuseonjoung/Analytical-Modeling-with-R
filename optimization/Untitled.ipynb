# %% [markdown]
# #### HW 15.2

# %%
# Loading the library
from pulp import *
import pandas as pd

# %%
# Loading the data
df = pd.read_excel("diet.xls")

# %% [markdown]
# ### Question 1

# %% [markdown]
# **1.	Formulate an optimization model (a linear program) to find the cheapest diet that satisfies the maximum and minimum daily nutrition constraints, and solve it using `PuLP`.  Turn in your code and the solution. (The optimal solution should be a diet of air-popped popcorn, poached eggs, oranges, raw iceberg lettuce, raw celery, and frozen broccoli. UGH!)**

# %% [markdown]
# #### Step 1: Loading the data

# %% [markdown]
# First, we need to load the data. Here we will use only until the 63th row, as these rows are containing the variables and the values.

# %%
## Change each row into list 
diet_df = df[0:64]
diet_df = diet_df.values.tolist()

# %%
df.head()
# Out:
#                  Foods  Price/ Serving      Serving Size  Calories  \
# 0      Frozen Broccoli            0.16         10 Oz Pkg      73.8
# 1          Carrots,Raw            0.07  1/2 Cup Shredded      23.7
# 2          Celery, Raw            0.04           1 Stalk       6.4
# 3          Frozen Corn            0.18           1/2 Cup      72.2
# 4  Lettuce,Iceberg,Raw            0.02            1 Leaf       2.6
#
#    Cholesterol mg  Total_Fat g  Sodium mg  Carbohydrates g  Dietary_Fiber g  \
# 0             0.0          0.8       68.2             13.6              8.5
# 1             0.0          0.1       19.2              5.6              1.6
# 2             0.0          0.1       34.8              1.5              0.7
# 3             0.0          0.6        2.5             17.1              2.0
# 4             0.0          0.0        1.8              0.4              0.3
#
#    Protein g  Vit_A IU  Vit_C IU  Calcium mg  Iron mg
# 0        8.0    5867.4     160.2       159.0      2.3
# 1        0.6   15471.0       5.1        14.9      0.3
# 2        0.3      53.6       2.8        16.0      0.2
# 3        2.5     106.6       5.2         3.3      0.3
# 4        0.2      66.0       0.8         3.8      0.1

# %% [markdown]
# #### Step 2: Modifying the format of the data for variables

# %% [markdown]
# In this part, we transform the information from the dataframe into dictionary for the necessary variables.
# We need three variables: 1) the amount of food, 2) the amount of nutrients per unit of food, and 3) the per-unit cost of food.
# Here, I saved the variables as a dictionary format. For easy calculation, I combined the dictionaries of the nutrients into a list, so that we can access the values like a matrix.

# %%
foods = [x[0] for x in diet_df]
calories = dict([(x[0], float(x[3])) for x in diet_df])
cholesterol = dict([(x[0], float(x[4])) for x in diet_df])
total_fat = dict([(x[0], float(x[5])) for x in diet_df])
sodium = dict([(x[0], float(x[6])) for x in diet_df])
carbohydrates = dict([(x[0], float(x[7])) for x in diet_df])
dietary_fiber = dict([(x[0], float(x[8])) for x in diet_df])
protein = dict([(x[0], float(x[9])) for x in diet_df])
vitamin_a = dict([(x[0], float(x[10])) for x in diet_df])
vitamin_c = dict([(x[0], float(x[11])) for x in diet_df])
calcium = dict([(x[0], float(x[12])) for x in diet_df])
iron = dict([(x[0], float(x[13])) for x in diet_df])

## Append the dictionary from calories to iron
B = []
for i in range(0,11):
    B.append(dict([(x[0], float(x[i+3])) for x in diet_df]))
    
## Cost data
cost = dict([(x[0], float(x[1])) for x in diet_df])

# %% [markdown]
# The minimum and maximum intake values were saved in a list to be used in the constraints.

# %%
# Create limits: from calories to iron 
min_take = [1500, 30, 20, 800, 130, 125, 60, 1000, 400, 700, 10]
max_take = [2500, 240, 70, 2000, 450, 250, 100, 10000, 5000, 1500, 40]

# %% [markdown]
# #### Step 3: Initializing the problem class

# %%
## Initializing the problem class - minimizing 
model1 = LpProblem("Optimized_diet_problem", LpMinimize)

# %% [markdown]
# #### Step 4: Setting the variables

# %%
## Foods variables as continuous 
foods_var = LpVariable.dicts("foods",foods, 0) # .dicts(name, indexs, lowBound=None, upBound=None, cat=0, indexStart=[])

# %%
## Chosen variable for each food
choice_var = LpVariable.dicts("chosen", foods, 0, 1, "Binary")

# %% [markdown]
# #### Step 5: Define objective function

# %% [markdown]
# As our objective is to minimize the expense for the diet that satisfies the daily nutrients intake, we set the objective function as the sum of the cost for the foods.

# %%
## Define the objective functions 
model1 += lpSum(cost[j]*foods_var[j] for j in foods)

# %% [markdown]
# #### Step 6: Add contraints

# %%
## Add constraints for minimum and maximum intake of nutrients

for i in range(0, 11): 
    B_x = pulp.lpSum([B[i][j] * foods_var[j] for j in foods]) # the total amount of nutrients intake 
    condition1 = min_take[i] <= + B_x
    model1 += condition1
    
for i in range(0, 11):
    B_x = pulp.lpSum([B[i][j] * foods_var[j] for j in foods]) # the total amount of nutrients intake 
    condition2 = max_take[i] >= + B_x
    model1 += condition2

# %% [markdown]
# #### Step 7: Solving the optimization problem

# %%
## Before solving the optimization, review the model built so far
print(model1)
# Out:
# Optimized_diet_problem:
# MINIMIZE
# 0.23*foods_2%_Lowfat_Milk + 0.16*foods_3.3%_Fat,Whole_Milk + 0.24*foods_Apple,Raw,W_Skin + 0.16*foods_Apple_Pie + 0.16*foods_Bagels + 0.15*foods_Banana + 0.67*foods_Beanbacn_Soup,W_Watr + 0.15*foods_Bologna,Turkey + 0.05*foods_Butter,Regular + 0.31*foods_Cap'N_Crunch + 0.07*foods_Carrots,Raw + 0.04*foods_Celery,_Raw + 0.25*foods_Cheddar_Cheese + 0.28*foods_Cheerios + 0.39*foods_Chicknoodl_Soup + 0.03*foods_Chocolate_Chip_Cookies + 0.28*foods_Corn_Flks,_Kellogg'S + 0.39*foods_Couscous + 0.65*foods_Crm_Mshrm_Soup,W_Mlk + 0.27*foods_Frankfurter,_Beef + 0.16*foods_Frozen_Broccoli + 0.18*foods_Frozen_Corn + 0.32*foods_Grapes + 0.33*foods_Ham,Sliced,Extralean + 0.83*foods_Hamburger_W_Toppings + 0.31*foods_Hotdog,_Plain + 0.15*foods_Kielbasa,Prk + 0.49*foods_Kiwifruit,Raw,Fresh + 0.02*foods_Lettuce,Iceberg,Raw + 0.17*foods_Macaroni,Ckd + 0.52*foods_Malt_O_Meal,Choc + 0.99*foods_New_E_Clamchwd,W_Mlk + 0.75*foods_Neweng_Clamchwd + 0.82*foods_Oatmeal + 0.09*foods_Oatmeal_Cookies + 0.15*foods_Oranges + 0.07*foods_Peanut_Butter + 0.53*foods_Peppers,_Sweet,_Raw + 0.44*foods_Pizza_W_Pepperoni + 0.08*foods_Poached_Eggs + 0.04*foods_Popcorn,Air_Popped + 0.81*foods_Pork + 0.22*foods_Potato_Chips,Bbqflvr + 0.06*foods_Potatoes,_Baked + 0.12*foods_Pretzels + 0.34*foods_Raisin_Brn,_Kellg'S + 0.32*foods_Rice_Krispies + 0.84*foods_Roasted_Chicken + 0.45*foods_Sardines_in_Oil + 0.11*foods_Scrambled_Eggs + 0.13*foods_Skim_Milk + 0.78*foods_Spaghetti_W__Sauce + 0.38*foods_Special_K + 0.67*foods_Splt_Pea&Hamsoup + 0.59*foods_Taco + 0.31*foods_Tofu + 0.27*foods_Tomato,Red,Ripe,Raw + 0.39*foods_Tomato_Soup + 0.19*foods_Tortilla_Chip + 0.71*foods_Vegetbeef_Soup + 0.05*foods_Wheat_Bread + 0.06*foods_White_Bread + 0.08*foods_White_Rice + 0.69*foods_White_Tuna_in_Water + 0.0
# SUBJECT TO
# _C1: 121.2 foods_2%_Lowfat_Milk + 149.9 foods_3.3%_Fat,Whole_Milk
#  + 81.4 foods_Apple,Raw,W_Skin + 67.2 foods_Apple_Pie + 78 foods_Bagels
#  + 104.9 foods_Banana + 172 foods_Beanbacn_Soup,W_Watr
#  + 56.4 foods_Bologna,Turkey + 35.8 foods_Butter,Regular
#  + 119.6 foods_Cap'N_Crunch + 23.7 foods_Carrots,Raw + 6.4 foods_Celery,_Raw
#  + 112.7 foods_Cheddar_Cheese + 111 foods_Cheerios
#  + 150.1 foods_Chicknoodl_Soup + 78.1 foods_Chocolate_Chip_Cookies
#  + 110.5 foods_Corn_Flks,_Kellogg'S + 100.8 foods_Couscous
#  + 203.4 foods_Crm_Mshrm_Soup,W_Mlk + 141.8 foods_Frankfurter,_Beef
#  + 73.8 foods_Frozen_Broccoli + 72.2 foods_Frozen_Corn + 15.1 foods_Grapes
#  + 37.1 foods_Ham,Sliced,Extralean + 275 foods_Hamburger_W_Toppings
#  + 242.1 foods_Hotdog,_Plain + 80.6 foods_Kielbasa,Prk
#  + 46.4 foods_Kiwifruit,Raw,Fresh + 2.6 foods_Lettuce,Iceberg,Raw
#  + 98.7 foods_Macaroni,Ckd + 607.2 foods_Malt_O_Meal,Choc
#  + 163.7 foods_New_E_Clamchwd,W_Mlk + 175.7 foods_Neweng_Clamchwd
#  + 145.1 foods_Oatmeal + 81 foods_Oatmeal_Cookies + 61.6 foods_Oranges
#  + 188.5 foods_Peanut_Butter + 20 foods_Peppers,_Sweet,_Raw
#  + 181 foods_Pizza_W_Pepperoni + 74.5 foods_Poached_Eggs
#  + 108.3 foods_Popcorn,Air_Popped + 710.8 foods_Pork
#  + 139.2 foods_Potato_Chips,Bbqflvr + 171.5 foods_Potatoes,_Baked
#  + 108 foods_Pretzels + 115.1 foods_Raisin_Brn,_Kellg'S
#  + 112.2 foods_Rice_Krispies + 277.4 foods_Roasted_Chicken
#  + 49.9 foods_Sardines_in_Oil + 99.6 foods_Scrambled_Eggs
#  + 85.5 foods_Skim_Milk + 358.2 foods_Spaghetti_W__Sauce
#  + 110.8 foods_Special_K + 184.8 foods_Splt_Pea&Hamsoup + 369.4 foods_Taco
#  + 88.2 foods_Tofu + 25.8 foods_Tomato,Red,Ripe,Raw + 170.7 foods_Tomato_Soup
#  + 142 foods_Tortilla_Chip + 158.1 foods_Vegetbeef_Soup + 65 foods_Wheat_Bread
#  + 65 foods_White_Bread + 102.7 foods_White_Rice
#  + 115.6 foods_White_Tuna_in_Water >= 1500
#
# _C2: 18.3 foods_2%_Lowfat_Milk + 33.2 foods_3.3%_Fat,Whole_Milk
#  + 2.5 foods_Beanbacn_Soup,W_Watr + 28.1 foods_Bologna,Turkey
#  + 10.9 foods_Butter,Regular + 29.4 foods_Cheddar_Cheese
#  + 12.3 foods_Chicknoodl_Soup + 5.1 foods_Chocolate_Chip_Cookies
#  + 19.8 foods_Crm_Mshrm_Soup,W_Mlk + 27.4 foods_Frankfurter,_Beef
#  + 13.3 foods_Ham,Sliced,Extralean + 42.8 foods_Hamburger_W_Toppings
#  + 44.1 foods_Hotdog,_Plain + 17.4 foods_Kielbasa,Prk
#  + 22.3 foods_New_E_Clamchwd,W_Mlk + 10 foods_Neweng_Clamchwd
#  + 14.2 foods_Pizza_W_Pepperoni + 211.5 foods_Poached_Eggs + 105.1 foods_Pork
#  + 129.9 foods_Roasted_Chicken + 34.1 foods_Sardines_in_Oil
#  + 211.2 foods_Scrambled_Eggs + 4.4 foods_Skim_Milk
#  + 7.2 foods_Splt_Pea&Hamsoup + 56.4 foods_Taco + 10 foods_Vegetbeef_Soup
#  + 35.7 foods_White_Tuna_in_Water >= 30
#
# _C3: 4.7 foods_2%_Lowfat_Milk + 8.1 foods_3.3%_Fat,Whole_Milk
#  + 0.5 foods_Apple,Raw,W_Skin + 3.1 foods_Apple_Pie + 0.5 foods_Bagels
#  + 0.5 foods_Banana + 5.9 foods_Beanbacn_Soup,W_Watr
#  + 4.3 foods_Bologna,Turkey + 4.1 foods_Butter,Regular
#  + 2.6 foods_Cap'N_Crunch + 0.1 foods_Carrots,Raw + 0.1 foods_Celery,_Raw
#  + 9.3 foods_Cheddar_Cheese + 1.8 foods_Cheerios + 4.6 foods_Chicknoodl_Soup
#  + 4.5 foods_Chocolate_Chip_Cookies + 0.1 foods_Corn_Flks,_Kellogg'S
#  + 0.1 foods_Couscous + 13.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 12.8 foods_Frankfurter,_Beef + 0.8 foods_Frozen_Broccoli
#  + 0.6 foods_Frozen_Corn + 0.1 foods_Grapes + 1.4 foods_Ham,Sliced,Extralean
#  + 10.2 foods_Hamburger_W_Toppings + 14.5 foods_Hotdog,_Plain
#  + 7.1 foods_Kielbasa,Prk + 0.3 foods_Kiwifruit,Raw,Fresh
#  + 0.5 foods_Macaroni,Ckd + 1.5 foods_Malt_O_Meal,Choc
#  + 6.6 foods_New_E_Clamchwd,W_Mlk + 5 foods_Neweng_Clamchwd
#  + 2.3 foods_Oatmeal + 3.3 foods_Oatmeal_Cookies + 0.2 foods_Oranges
#  + 16 foods_Peanut_Butter + 0.1 foods_Peppers,_Sweet,_Raw
#  + 7 foods_Pizza_W_Pepperoni + 5 foods_Poached_Eggs
#  + 1.2 foods_Popcorn,Air_Popped + 72.2 foods_Pork
#  + 9.2 foods_Potato_Chips,Bbqflvr + 0.2 foods_Potatoes,_Baked + foods_Pretzels
#  + 0.7 foods_Raisin_Brn,_Kellg'S + 0.2 foods_Rice_Krispies
#  + 10.8 foods_Roasted_Chicken + 2.7 foods_Sardines_in_Oil
#  + 7.3 foods_Scrambled_Eggs + 0.4 foods_Skim_Milk
#  + 12.3 foods_Spaghetti_W__Sauce + 0.1 foods_Special_K
#  + 4 foods_Splt_Pea&Hamsoup + 20.6 foods_Taco + 5.5 foods_Tofu
#  + 0.4 foods_Tomato,Red,Ripe,Raw + 3.8 foods_Tomato_Soup
#  + 7.4 foods_Tortilla_Chip + 3.8 foods_Vegetbeef_Soup + foods_Wheat_Bread
#  + foods_White_Bread + 0.2 foods_White_Rice + 2.1 foods_White_Tuna_in_Water
#  >= 20
#
# _C4: 121.8 foods_2%_Lowfat_Milk + 119.6 foods_3.3%_Fat,Whole_Milk
#  + 75.4 foods_Apple_Pie + 151.4 foods_Bagels + 1.1 foods_Banana
#  + 951.3 foods_Beanbacn_Soup,W_Watr + 248.9 foods_Bologna,Turkey
#  + 41.3 foods_Butter,Regular + 213.3 foods_Cap'N_Crunch
#  + 19.2 foods_Carrots,Raw + 34.8 foods_Celery,_Raw
#  + 173.7 foods_Cheddar_Cheese + 307.6 foods_Cheerios
#  + 1862.2 foods_Chicknoodl_Soup + 57.8 foods_Chocolate_Chip_Cookies
#  + 290.5 foods_Corn_Flks,_Kellogg'S + 4.5 foods_Couscous
#  + 1076.3 foods_Crm_Mshrm_Soup,W_Mlk + 461.7 foods_Frankfurter,_Beef
#  + 68.2 foods_Frozen_Broccoli + 2.5 foods_Frozen_Corn + 0.5 foods_Grapes
#  + 405.1 foods_Ham,Sliced,Extralean + 563.9 foods_Hamburger_W_Toppings
#  + 670.3 foods_Hotdog,_Plain + 279.8 foods_Kielbasa,Prk
#  + 3.8 foods_Kiwifruit,Raw,Fresh + 1.8 foods_Lettuce,Iceberg,Raw
#  + 0.7 foods_Macaroni,Ckd + 16.5 foods_Malt_O_Meal,Choc
#  + 992 foods_New_E_Clamchwd,W_Mlk + 1864.9 foods_Neweng_Clamchwd
#  + 2.3 foods_Oatmeal + 68.9 foods_Oatmeal_Cookies + 155.5 foods_Peanut_Butter
#  + 1.5 foods_Peppers,_Sweet,_Raw + 267 foods_Pizza_W_Pepperoni
#  + 140 foods_Poached_Eggs + 1.1 foods_Popcorn,Air_Popped + 38.4 foods_Pork
#  + 212.6 foods_Potato_Chips,Bbqflvr + 15.2 foods_Potatoes,_Baked
#  + 486.2 foods_Pretzels + 204.4 foods_Raisin_Brn,_Kellg'S
#  + 340.8 foods_Rice_Krispies + 125.6 foods_Roasted_Chicken
#  + 121.2 foods_Sardines_in_Oil + 168 foods_Scrambled_Eggs
#  + 126.2 foods_Skim_Milk + 1237.1 foods_Spaghetti_W__Sauce
#  + 265.5 foods_Special_K + 964.8 foods_Splt_Pea&Hamsoup + 802 foods_Taco
#  + 8.1 foods_Tofu + 11.1 foods_Tomato,Red,Ripe,Raw + 1744.4 foods_Tomato_Soup
#  + 149.7 foods_Tortilla_Chip + 1915.1 foods_Vegetbeef_Soup
#  + 134.5 foods_Wheat_Bread + 132.5 foods_White_Bread + 0.8 foods_White_Rice
#  + 333.2 foods_White_Tuna_in_Water >= 800
#
# _C5: 11.7 foods_2%_Lowfat_Milk + 11.4 foods_3.3%_Fat,Whole_Milk
#  + 21 foods_Apple,Raw,W_Skin + 9.6 foods_Apple_Pie + 15.1 foods_Bagels
#  + 26.7 foods_Banana + 22.8 foods_Beanbacn_Soup,W_Watr
#  + 0.3 foods_Bologna,Turkey + 23 foods_Cap'N_Crunch + 5.6 foods_Carrots,Raw
#  + 1.5 foods_Celery,_Raw + 0.4 foods_Cheddar_Cheese + 19.6 foods_Cheerios
#  + 18.7 foods_Chicknoodl_Soup + 9.3 foods_Chocolate_Chip_Cookies
#  + 24.5 foods_Corn_Flks,_Kellogg'S + 20.9 foods_Couscous
#  + 15 foods_Crm_Mshrm_Soup,W_Mlk + 0.8 foods_Frankfurter,_Beef
#  + 13.6 foods_Frozen_Broccoli + 17.1 foods_Frozen_Corn + 4.1 foods_Grapes
#  + 0.3 foods_Ham,Sliced,Extralean + 32.7 foods_Hamburger_W_Toppings
#  + 18 foods_Hotdog,_Plain + 0.6 foods_Kielbasa,Prk
#  + 11.3 foods_Kiwifruit,Raw,Fresh + 0.4 foods_Lettuce,Iceberg,Raw
#  + 19.8 foods_Macaroni,Ckd + 128.2 foods_Malt_O_Meal,Choc
#  + 16.6 foods_New_E_Clamchwd,W_Mlk + 21.8 foods_Neweng_Clamchwd
#  + 25.3 foods_Oatmeal + 12.4 foods_Oatmeal_Cookies + 15.4 foods_Oranges
#  + 6.9 foods_Peanut_Butter + 4.8 foods_Peppers,_Sweet,_Raw
#  + 19.9 foods_Pizza_W_Pepperoni + 0.6 foods_Poached_Eggs
#  + 22.1 foods_Popcorn,Air_Popped + 15 foods_Potato_Chips,Bbqflvr
#  + 39.9 foods_Potatoes,_Baked + 22.5 foods_Pretzels
#  + 27.9 foods_Raisin_Brn,_Kellg'S + 24.8 foods_Rice_Krispies
#  + 1.3 foods_Scrambled_Eggs + 11.9 foods_Skim_Milk
#  + 58.3 foods_Spaghetti_W__Sauce + 21.3 foods_Special_K
#  + 26.8 foods_Splt_Pea&Hamsoup + 26.7 foods_Taco + 2.2 foods_Tofu
#  + 5.7 foods_Tomato,Red,Ripe,Raw + 33.2 foods_Tomato_Soup
#  + 17.8 foods_Tortilla_Chip + 20.4 foods_Vegetbeef_Soup
#  + 12.4 foods_Wheat_Bread + 11.8 foods_White_Bread + 22.3 foods_White_Rice
#  >= 130
#
# _C6: 3.7 foods_Apple,Raw,W_Skin + 0.5 foods_Apple_Pie + 0.6 foods_Bagels
#  + 2.7 foods_Banana + 8.6 foods_Beanbacn_Soup,W_Watr + 0.5 foods_Cap'N_Crunch
#  + 1.6 foods_Carrots,Raw + 0.7 foods_Celery,_Raw + 2 foods_Cheerios
#  + 1.5 foods_Chicknoodl_Soup + 0.7 foods_Corn_Flks,_Kellogg'S
#  + 1.3 foods_Couscous + 0.5 foods_Crm_Mshrm_Soup,W_Mlk
#  + 8.5 foods_Frozen_Broccoli + 2 foods_Frozen_Corn + 0.2 foods_Grapes
#  + 2.6 foods_Kiwifruit,Raw,Fresh + 0.3 foods_Lettuce,Iceberg,Raw
#  + 0.9 foods_Macaroni,Ckd + 1.5 foods_New_E_Clamchwd,W_Mlk
#  + 1.5 foods_Neweng_Clamchwd + 4 foods_Oatmeal + 0.6 foods_Oatmeal_Cookies
#  + 3.1 foods_Oranges + 2.1 foods_Peanut_Butter + 1.3 foods_Peppers,_Sweet,_Raw
#  + 4.3 foods_Popcorn,Air_Popped + 1.2 foods_Potato_Chips,Bbqflvr
#  + 3.2 foods_Potatoes,_Baked + 0.9 foods_Pretzels
#  + 4 foods_Raisin_Brn,_Kellg'S + 0.4 foods_Rice_Krispies
#  + 11.6 foods_Spaghetti_W__Sauce + 0.7 foods_Special_K
#  + 4.1 foods_Splt_Pea&Hamsoup + 1.4 foods_Tofu + 1.4 foods_Tomato,Red,Ripe,Raw
#  + foods_Tomato_Soup + 1.8 foods_Tortilla_Chip + 4 foods_Vegetbeef_Soup
#  + 1.3 foods_Wheat_Bread + 1.1 foods_White_Bread + 0.3 foods_White_Rice >= 125
#
# _C7: 8.1 foods_2%_Lowfat_Milk + 8 foods_3.3%_Fat,Whole_Milk
#  + 0.3 foods_Apple,Raw,W_Skin + 0.5 foods_Apple_Pie + 3 foods_Bagels
#  + 1.2 foods_Banana + 7.9 foods_Beanbacn_Soup,W_Watr
#  + 3.9 foods_Bologna,Turkey + 1.4 foods_Cap'N_Crunch + 0.6 foods_Carrots,Raw
#  + 0.3 foods_Celery,_Raw + 7 foods_Cheddar_Cheese + 4.3 foods_Cheerios
#  + 7.9 foods_Chicknoodl_Soup + 0.9 foods_Chocolate_Chip_Cookies
#  + 2.3 foods_Corn_Flks,_Kellogg'S + 3.4 foods_Couscous
#  + 6.1 foods_Crm_Mshrm_Soup,W_Mlk + 5.4 foods_Frankfurter,_Beef
#  + 8 foods_Frozen_Broccoli + 2.5 foods_Frozen_Corn + 0.2 foods_Grapes
#  + 5.5 foods_Ham,Sliced,Extralean + 13.6 foods_Hamburger_W_Toppings
#  + 10.4 foods_Hotdog,_Plain + 3.4 foods_Kielbasa,Prk
#  + 0.8 foods_Kiwifruit,Raw,Fresh + 0.2 foods_Lettuce,Iceberg,Raw
#  + 3.3 foods_Macaroni,Ckd + 17.3 foods_Malt_O_Meal,Choc
#  + 9.5 foods_New_E_Clamchwd,W_Mlk + 10.9 foods_Neweng_Clamchwd
#  + 6.1 foods_Oatmeal + 1.1 foods_Oatmeal_Cookies + 1.2 foods_Oranges
#  + 7.7 foods_Peanut_Butter + 0.7 foods_Peppers,_Sweet,_Raw
#  + 10.1 foods_Pizza_W_Pepperoni + 6.2 foods_Poached_Eggs
#  + 3.4 foods_Popcorn,Air_Popped + 13.8 foods_Pork
#  + 2.2 foods_Potato_Chips,Bbqflvr + 3.7 foods_Potatoes,_Baked
#  + 2.6 foods_Pretzels + 4 foods_Raisin_Brn,_Kellg'S + 1.9 foods_Rice_Krispies
#  + 42.2 foods_Roasted_Chicken + 5.9 foods_Sardines_in_Oil
#  + 6.7 foods_Scrambled_Eggs + 8.4 foods_Skim_Milk
#  + 8.2 foods_Spaghetti_W__Sauce + 5.6 foods_Special_K
#  + 11.1 foods_Splt_Pea&Hamsoup + 20.7 foods_Taco + 9.4 foods_Tofu
#  + foods_Tomato,Red,Ripe,Raw + 4.1 foods_Tomato_Soup + 2 foods_Tortilla_Chip
#  + 11.2 foods_Vegetbeef_Soup + 2.2 foods_Wheat_Bread + 2.3 foods_White_Bread
#  + 2.1 foods_White_Rice + 22.7 foods_White_Tuna_in_Water >= 60
#
# _C8: 500.2 foods_2%_Lowfat_Milk + 307.4 foods_3.3%_Fat,Whole_Milk
#  + 73.1 foods_Apple,Raw,W_Skin + 35.2 foods_Apple_Pie + 92.3 foods_Banana
#  + 888 foods_Beanbacn_Soup,W_Watr + 152.9 foods_Butter,Regular
#  + 40.6 foods_Cap'N_Crunch + 15471 foods_Carrots,Raw + 53.6 foods_Celery,_Raw
#  + 296.5 foods_Cheddar_Cheese + 1252.2 foods_Cheerios
#  + 1308.7 foods_Chicknoodl_Soup + 101.8 foods_Chocolate_Chip_Cookies
#  + 1252.2 foods_Corn_Flks,_Kellogg'S + 153.8 foods_Crm_Mshrm_Soup,W_Mlk
#  + 5867.4 foods_Frozen_Broccoli + 106.6 foods_Frozen_Corn + 24 foods_Grapes
#  + 126.3 foods_Hamburger_W_Toppings + 133 foods_Kiwifruit,Raw,Fresh
#  + 66 foods_Lettuce,Iceberg,Raw + 163.7 foods_New_E_Clamchwd,W_Mlk
#  + 20.1 foods_Neweng_Clamchwd + 37.4 foods_Oatmeal + 2.9 foods_Oatmeal_Cookies
#  + 268.6 foods_Oranges + 467.7 foods_Peppers,_Sweet,_Raw
#  + 281.9 foods_Pizza_W_Pepperoni + 316 foods_Poached_Eggs
#  + 55.6 foods_Popcorn,Air_Popped + 14.7 foods_Pork
#  + 61.5 foods_Potato_Chips,Bbqflvr + 1250.2 foods_Raisin_Brn,_Kellg'S
#  + 1252.2 foods_Rice_Krispies + 77.4 foods_Roasted_Chicken
#  + 53.8 foods_Sardines_in_Oil + 409.2 foods_Scrambled_Eggs
#  + 499.8 foods_Skim_Milk + 3055.2 foods_Spaghetti_W__Sauce
#  + 1252.2 foods_Special_K + 4872 foods_Splt_Pea&Hamsoup + 855 foods_Taco
#  + 98.6 foods_Tofu + 766.3 foods_Tomato,Red,Ripe,Raw + 1393 foods_Tomato_Soup
#  + 55.6 foods_Tortilla_Chip + 3785.1 foods_Vegetbeef_Soup
#  + 68 foods_White_Tuna_in_Water >= 1000
#
# _C9: 2.3 foods_2%_Lowfat_Milk + 2.3 foods_3.3%_Fat,Whole_Milk
#  + 7.9 foods_Apple,Raw,W_Skin + 0.9 foods_Apple_Pie + 10.4 foods_Banana
#  + 1.5 foods_Beanbacn_Soup,W_Watr + 5.1 foods_Carrots,Raw
#  + 2.8 foods_Celery,_Raw + 15.1 foods_Cheerios
#  + 15.1 foods_Corn_Flks,_Kellogg'S + 2.2 foods_Crm_Mshrm_Soup,W_Mlk
#  + 10.8 foods_Frankfurter,_Beef + 160.2 foods_Frozen_Broccoli
#  + 5.2 foods_Frozen_Corn + foods_Grapes + 7.4 foods_Ham,Sliced,Extralean
#  + 2.6 foods_Hamburger_W_Toppings + 0.1 foods_Hotdog,_Plain
#  + 5.5 foods_Kielbasa,Prk + 74.5 foods_Kiwifruit,Raw,Fresh
#  + 0.8 foods_Lettuce,Iceberg,Raw + 3.5 foods_New_E_Clamchwd,W_Mlk
#  + 4.8 foods_Neweng_Clamchwd + 0.1 foods_Oatmeal_Cookies + 69.7 foods_Oranges
#  + 66.1 foods_Peppers,_Sweet,_Raw + 1.6 foods_Pizza_W_Pepperoni
#  + 9.6 foods_Potato_Chips,Bbqflvr + 15.6 foods_Potatoes,_Baked
#  + 15.1 foods_Rice_Krispies + 0.1 foods_Scrambled_Eggs + 2.4 foods_Skim_Milk
#  + 27.9 foods_Spaghetti_W__Sauce + 15.1 foods_Special_K
#  + 7 foods_Splt_Pea&Hamsoup + 2.2 foods_Taco + 0.1 foods_Tofu
#  + 23.5 foods_Tomato,Red,Ripe,Raw + 133 foods_Tomato_Soup
#  + 4.8 foods_Vegetbeef_Soup >= 400
#
# _C10: 296.7 foods_2%_Lowfat_Milk + 291.3 foods_3.3%_Fat,Whole_Milk
#  + 9.7 foods_Apple,Raw,W_Skin + 3.1 foods_Apple_Pie + 21 foods_Bagels
#  + 6.8 foods_Banana + 81 foods_Beanbacn_Soup,W_Watr
#  + 23.8 foods_Bologna,Turkey + 1.2 foods_Butter,Regular
#  + 4.8 foods_Cap'N_Crunch + 14.9 foods_Carrots,Raw + 16 foods_Celery,_Raw
#  + 202 foods_Cheddar_Cheese + 48.6 foods_Cheerios + 27.1 foods_Chicknoodl_Soup
#  + 6.2 foods_Chocolate_Chip_Cookies + 0.9 foods_Corn_Flks,_Kellogg'S
#  + 7.2 foods_Couscous + 178.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 9 foods_Frankfurter,_Beef + 159 foods_Frozen_Broccoli
#  + 3.3 foods_Frozen_Corn + 3.4 foods_Grapes + 2 foods_Ham,Sliced,Extralean
#  + 51.4 foods_Hamburger_W_Toppings + 23.5 foods_Hotdog,_Plain
#  + 11.4 foods_Kielbasa,Prk + 19.8 foods_Kiwifruit,Raw,Fresh
#  + 3.8 foods_Lettuce,Iceberg,Raw + 4.9 foods_Macaroni,Ckd
#  + 23.1 foods_Malt_O_Meal,Choc + 186 foods_New_E_Clamchwd,W_Mlk
#  + 82.8 foods_Neweng_Clamchwd + 18.7 foods_Oatmeal + 6.7 foods_Oatmeal_Cookies
#  + 52.4 foods_Oranges + 13.1 foods_Peanut_Butter
#  + 6.7 foods_Peppers,_Sweet,_Raw + 64.6 foods_Pizza_W_Pepperoni
#  + 24.5 foods_Poached_Eggs + 2.8 foods_Popcorn,Air_Popped + 59.9 foods_Pork
#  + 14.2 foods_Potato_Chips,Bbqflvr + 22.7 foods_Potatoes,_Baked
#  + 10.2 foods_Pretzels + 12.9 foods_Raisin_Brn,_Kellg'S
#  + 4 foods_Rice_Krispies + 21.9 foods_Roasted_Chicken
#  + 91.7 foods_Sardines_in_Oil + 42.6 foods_Scrambled_Eggs
#  + 302.3 foods_Skim_Milk + 80.2 foods_Spaghetti_W__Sauce + 8.2 foods_Special_K
#  + 33.6 foods_Splt_Pea&Hamsoup + 220.6 foods_Taco + 121.8 foods_Tofu
#  + 6.2 foods_Tomato,Red,Ripe,Raw + 27.6 foods_Tomato_Soup
#  + 43.7 foods_Tortilla_Chip + 32.6 foods_Vegetbeef_Soup
#  + 10.8 foods_Wheat_Bread + 26.2 foods_White_Bread + 7.9 foods_White_Rice
#  + 3.4 foods_White_Tuna_in_Water >= 700
#
# _C11: 0.1 foods_2%_Lowfat_Milk + 0.1 foods_3.3%_Fat,Whole_Milk
#  + 0.2 foods_Apple,Raw,W_Skin + 0.1 foods_Apple_Pie + foods_Bagels
#  + 0.4 foods_Banana + 2 foods_Beanbacn_Soup,W_Watr + 0.4 foods_Bologna,Turkey
#  + 7.5 foods_Cap'N_Crunch + 0.3 foods_Carrots,Raw + 0.2 foods_Celery,_Raw
#  + 0.2 foods_Cheddar_Cheese + 4.5 foods_Cheerios + 1.5 foods_Chicknoodl_Soup
#  + 0.4 foods_Chocolate_Chip_Cookies + 1.8 foods_Corn_Flks,_Kellogg'S
#  + 0.3 foods_Couscous + 0.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 0.6 foods_Frankfurter,_Beef + 2.3 foods_Frozen_Broccoli
#  + 0.3 foods_Frozen_Corn + 0.1 foods_Grapes + 0.2 foods_Ham,Sliced,Extralean
#  + 2.5 foods_Hamburger_W_Toppings + 2.3 foods_Hotdog,_Plain
#  + 0.4 foods_Kielbasa,Prk + 0.3 foods_Kiwifruit,Raw,Fresh
#  + 0.1 foods_Lettuce,Iceberg,Raw + foods_Macaroni,Ckd
#  + 4.7 foods_Malt_O_Meal,Choc + 1.5 foods_New_E_Clamchwd,W_Mlk
#  + 2.8 foods_Neweng_Clamchwd + 1.6 foods_Oatmeal + 0.5 foods_Oatmeal_Cookies
#  + 0.1 foods_Oranges + 0.6 foods_Peanut_Butter + 0.3 foods_Peppers,_Sweet,_Raw
#  + 0.9 foods_Pizza_W_Pepperoni + 0.7 foods_Poached_Eggs
#  + 0.8 foods_Popcorn,Air_Popped + 0.4 foods_Pork
#  + 0.5 foods_Potato_Chips,Bbqflvr + 4.3 foods_Potatoes,_Baked
#  + 1.2 foods_Pretzels + 16.8 foods_Raisin_Brn,_Kellg'S
#  + 1.8 foods_Rice_Krispies + 1.8 foods_Roasted_Chicken
#  + 0.7 foods_Sardines_in_Oil + 0.7 foods_Scrambled_Eggs + 0.1 foods_Skim_Milk
#  + 2.3 foods_Spaghetti_W__Sauce + 4.5 foods_Special_K
#  + 2.1 foods_Splt_Pea&Hamsoup + 2.4 foods_Taco + 6.2 foods_Tofu
#  + 0.6 foods_Tomato,Red,Ripe,Raw + 3.5 foods_Tomato_Soup
#  + 0.4 foods_Tortilla_Chip + 2.2 foods_Vegetbeef_Soup + 0.7 foods_Wheat_Bread
#  + 0.8 foods_White_Bread + 0.9 foods_White_Rice
#  + 0.5 foods_White_Tuna_in_Water >= 10
#
# _C12: 121.2 foods_2%_Lowfat_Milk + 149.9 foods_3.3%_Fat,Whole_Milk
#  + 81.4 foods_Apple,Raw,W_Skin + 67.2 foods_Apple_Pie + 78 foods_Bagels
#  + 104.9 foods_Banana + 172 foods_Beanbacn_Soup,W_Watr
#  + 56.4 foods_Bologna,Turkey + 35.8 foods_Butter,Regular
#  + 119.6 foods_Cap'N_Crunch + 23.7 foods_Carrots,Raw + 6.4 foods_Celery,_Raw
#  + 112.7 foods_Cheddar_Cheese + 111 foods_Cheerios
#  + 150.1 foods_Chicknoodl_Soup + 78.1 foods_Chocolate_Chip_Cookies
#  + 110.5 foods_Corn_Flks,_Kellogg'S + 100.8 foods_Couscous
#  + 203.4 foods_Crm_Mshrm_Soup,W_Mlk + 141.8 foods_Frankfurter,_Beef
#  + 73.8 foods_Frozen_Broccoli + 72.2 foods_Frozen_Corn + 15.1 foods_Grapes
#  + 37.1 foods_Ham,Sliced,Extralean + 275 foods_Hamburger_W_Toppings
#  + 242.1 foods_Hotdog,_Plain + 80.6 foods_Kielbasa,Prk
#  + 46.4 foods_Kiwifruit,Raw,Fresh + 2.6 foods_Lettuce,Iceberg,Raw
#  + 98.7 foods_Macaroni,Ckd + 607.2 foods_Malt_O_Meal,Choc
#  + 163.7 foods_New_E_Clamchwd,W_Mlk + 175.7 foods_Neweng_Clamchwd
#  + 145.1 foods_Oatmeal + 81 foods_Oatmeal_Cookies + 61.6 foods_Oranges
#  + 188.5 foods_Peanut_Butter + 20 foods_Peppers,_Sweet,_Raw
#  + 181 foods_Pizza_W_Pepperoni + 74.5 foods_Poached_Eggs
#  + 108.3 foods_Popcorn,Air_Popped + 710.8 foods_Pork
#  + 139.2 foods_Potato_Chips,Bbqflvr + 171.5 foods_Potatoes,_Baked
#  + 108 foods_Pretzels + 115.1 foods_Raisin_Brn,_Kellg'S
#  + 112.2 foods_Rice_Krispies + 277.4 foods_Roasted_Chicken
#  + 49.9 foods_Sardines_in_Oil + 99.6 foods_Scrambled_Eggs
#  + 85.5 foods_Skim_Milk + 358.2 foods_Spaghetti_W__Sauce
#  + 110.8 foods_Special_K + 184.8 foods_Splt_Pea&Hamsoup + 369.4 foods_Taco
#  + 88.2 foods_Tofu + 25.8 foods_Tomato,Red,Ripe,Raw + 170.7 foods_Tomato_Soup
#  + 142 foods_Tortilla_Chip + 158.1 foods_Vegetbeef_Soup + 65 foods_Wheat_Bread
#  + 65 foods_White_Bread + 102.7 foods_White_Rice
#  + 115.6 foods_White_Tuna_in_Water <= 2500
#
# _C13: 18.3 foods_2%_Lowfat_Milk + 33.2 foods_3.3%_Fat,Whole_Milk
#  + 2.5 foods_Beanbacn_Soup,W_Watr + 28.1 foods_Bologna,Turkey
#  + 10.9 foods_Butter,Regular + 29.4 foods_Cheddar_Cheese
#  + 12.3 foods_Chicknoodl_Soup + 5.1 foods_Chocolate_Chip_Cookies
#  + 19.8 foods_Crm_Mshrm_Soup,W_Mlk + 27.4 foods_Frankfurter,_Beef
#  + 13.3 foods_Ham,Sliced,Extralean + 42.8 foods_Hamburger_W_Toppings
#  + 44.1 foods_Hotdog,_Plain + 17.4 foods_Kielbasa,Prk
#  + 22.3 foods_New_E_Clamchwd,W_Mlk + 10 foods_Neweng_Clamchwd
#  + 14.2 foods_Pizza_W_Pepperoni + 211.5 foods_Poached_Eggs + 105.1 foods_Pork
#  + 129.9 foods_Roasted_Chicken + 34.1 foods_Sardines_in_Oil
#  + 211.2 foods_Scrambled_Eggs + 4.4 foods_Skim_Milk
#  + 7.2 foods_Splt_Pea&Hamsoup + 56.4 foods_Taco + 10 foods_Vegetbeef_Soup
#  + 35.7 foods_White_Tuna_in_Water <= 240
#
# _C14: 4.7 foods_2%_Lowfat_Milk + 8.1 foods_3.3%_Fat,Whole_Milk
#  + 0.5 foods_Apple,Raw,W_Skin + 3.1 foods_Apple_Pie + 0.5 foods_Bagels
#  + 0.5 foods_Banana + 5.9 foods_Beanbacn_Soup,W_Watr
#  + 4.3 foods_Bologna,Turkey + 4.1 foods_Butter,Regular
#  + 2.6 foods_Cap'N_Crunch + 0.1 foods_Carrots,Raw + 0.1 foods_Celery,_Raw
#  + 9.3 foods_Cheddar_Cheese + 1.8 foods_Cheerios + 4.6 foods_Chicknoodl_Soup
#  + 4.5 foods_Chocolate_Chip_Cookies + 0.1 foods_Corn_Flks,_Kellogg'S
#  + 0.1 foods_Couscous + 13.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 12.8 foods_Frankfurter,_Beef + 0.8 foods_Frozen_Broccoli
#  + 0.6 foods_Frozen_Corn + 0.1 foods_Grapes + 1.4 foods_Ham,Sliced,Extralean
#  + 10.2 foods_Hamburger_W_Toppings + 14.5 foods_Hotdog,_Plain
#  + 7.1 foods_Kielbasa,Prk + 0.3 foods_Kiwifruit,Raw,Fresh
#  + 0.5 foods_Macaroni,Ckd + 1.5 foods_Malt_O_Meal,Choc
#  + 6.6 foods_New_E_Clamchwd,W_Mlk + 5 foods_Neweng_Clamchwd
#  + 2.3 foods_Oatmeal + 3.3 foods_Oatmeal_Cookies + 0.2 foods_Oranges
#  + 16 foods_Peanut_Butter + 0.1 foods_Peppers,_Sweet,_Raw
#  + 7 foods_Pizza_W_Pepperoni + 5 foods_Poached_Eggs
#  + 1.2 foods_Popcorn,Air_Popped + 72.2 foods_Pork
#  + 9.2 foods_Potato_Chips,Bbqflvr + 0.2 foods_Potatoes,_Baked + foods_Pretzels
#  + 0.7 foods_Raisin_Brn,_Kellg'S + 0.2 foods_Rice_Krispies
#  + 10.8 foods_Roasted_Chicken + 2.7 foods_Sardines_in_Oil
#  + 7.3 foods_Scrambled_Eggs + 0.4 foods_Skim_Milk
#  + 12.3 foods_Spaghetti_W__Sauce + 0.1 foods_Special_K
#  + 4 foods_Splt_Pea&Hamsoup + 20.6 foods_Taco + 5.5 foods_Tofu
#  + 0.4 foods_Tomato,Red,Ripe,Raw + 3.8 foods_Tomato_Soup
#  + 7.4 foods_Tortilla_Chip + 3.8 foods_Vegetbeef_Soup + foods_Wheat_Bread
#  + foods_White_Bread + 0.2 foods_White_Rice + 2.1 foods_White_Tuna_in_Water
#  <= 70
#
# _C15: 121.8 foods_2%_Lowfat_Milk + 119.6 foods_3.3%_Fat,Whole_Milk
#  + 75.4 foods_Apple_Pie + 151.4 foods_Bagels + 1.1 foods_Banana
#  + 951.3 foods_Beanbacn_Soup,W_Watr + 248.9 foods_Bologna,Turkey
#  + 41.3 foods_Butter,Regular + 213.3 foods_Cap'N_Crunch
#  + 19.2 foods_Carrots,Raw + 34.8 foods_Celery,_Raw
#  + 173.7 foods_Cheddar_Cheese + 307.6 foods_Cheerios
#  + 1862.2 foods_Chicknoodl_Soup + 57.8 foods_Chocolate_Chip_Cookies
#  + 290.5 foods_Corn_Flks,_Kellogg'S + 4.5 foods_Couscous
#  + 1076.3 foods_Crm_Mshrm_Soup,W_Mlk + 461.7 foods_Frankfurter,_Beef
#  + 68.2 foods_Frozen_Broccoli + 2.5 foods_Frozen_Corn + 0.5 foods_Grapes
#  + 405.1 foods_Ham,Sliced,Extralean + 563.9 foods_Hamburger_W_Toppings
#  + 670.3 foods_Hotdog,_Plain + 279.8 foods_Kielbasa,Prk
#  + 3.8 foods_Kiwifruit,Raw,Fresh + 1.8 foods_Lettuce,Iceberg,Raw
#  + 0.7 foods_Macaroni,Ckd + 16.5 foods_Malt_O_Meal,Choc
#  + 992 foods_New_E_Clamchwd,W_Mlk + 1864.9 foods_Neweng_Clamchwd
#  + 2.3 foods_Oatmeal + 68.9 foods_Oatmeal_Cookies + 155.5 foods_Peanut_Butter
#  + 1.5 foods_Peppers,_Sweet,_Raw + 267 foods_Pizza_W_Pepperoni
#  + 140 foods_Poached_Eggs + 1.1 foods_Popcorn,Air_Popped + 38.4 foods_Pork
#  + 212.6 foods_Potato_Chips,Bbqflvr + 15.2 foods_Potatoes,_Baked
#  + 486.2 foods_Pretzels + 204.4 foods_Raisin_Brn,_Kellg'S
#  + 340.8 foods_Rice_Krispies + 125.6 foods_Roasted_Chicken
#  + 121.2 foods_Sardines_in_Oil + 168 foods_Scrambled_Eggs
#  + 126.2 foods_Skim_Milk + 1237.1 foods_Spaghetti_W__Sauce
#  + 265.5 foods_Special_K + 964.8 foods_Splt_Pea&Hamsoup + 802 foods_Taco
#  + 8.1 foods_Tofu + 11.1 foods_Tomato,Red,Ripe,Raw + 1744.4 foods_Tomato_Soup
#  + 149.7 foods_Tortilla_Chip + 1915.1 foods_Vegetbeef_Soup
#  + 134.5 foods_Wheat_Bread + 132.5 foods_White_Bread + 0.8 foods_White_Rice
#  + 333.2 foods_White_Tuna_in_Water <= 2000
#
# _C16: 11.7 foods_2%_Lowfat_Milk + 11.4 foods_3.3%_Fat,Whole_Milk
#  + 21 foods_Apple,Raw,W_Skin + 9.6 foods_Apple_Pie + 15.1 foods_Bagels
#  + 26.7 foods_Banana + 22.8 foods_Beanbacn_Soup,W_Watr
#  + 0.3 foods_Bologna,Turkey + 23 foods_Cap'N_Crunch + 5.6 foods_Carrots,Raw
#  + 1.5 foods_Celery,_Raw + 0.4 foods_Cheddar_Cheese + 19.6 foods_Cheerios
#  + 18.7 foods_Chicknoodl_Soup + 9.3 foods_Chocolate_Chip_Cookies
#  + 24.5 foods_Corn_Flks,_Kellogg'S + 20.9 foods_Couscous
#  + 15 foods_Crm_Mshrm_Soup,W_Mlk + 0.8 foods_Frankfurter,_Beef
#  + 13.6 foods_Frozen_Broccoli + 17.1 foods_Frozen_Corn + 4.1 foods_Grapes
#  + 0.3 foods_Ham,Sliced,Extralean + 32.7 foods_Hamburger_W_Toppings
#  + 18 foods_Hotdog,_Plain + 0.6 foods_Kielbasa,Prk
#  + 11.3 foods_Kiwifruit,Raw,Fresh + 0.4 foods_Lettuce,Iceberg,Raw
#  + 19.8 foods_Macaroni,Ckd + 128.2 foods_Malt_O_Meal,Choc
#  + 16.6 foods_New_E_Clamchwd,W_Mlk + 21.8 foods_Neweng_Clamchwd
#  + 25.3 foods_Oatmeal + 12.4 foods_Oatmeal_Cookies + 15.4 foods_Oranges
#  + 6.9 foods_Peanut_Butter + 4.8 foods_Peppers,_Sweet,_Raw
#  + 19.9 foods_Pizza_W_Pepperoni + 0.6 foods_Poached_Eggs
#  + 22.1 foods_Popcorn,Air_Popped + 15 foods_Potato_Chips,Bbqflvr
#  + 39.9 foods_Potatoes,_Baked + 22.5 foods_Pretzels
#  + 27.9 foods_Raisin_Brn,_Kellg'S + 24.8 foods_Rice_Krispies
#  + 1.3 foods_Scrambled_Eggs + 11.9 foods_Skim_Milk
#  + 58.3 foods_Spaghetti_W__Sauce + 21.3 foods_Special_K
#  + 26.8 foods_Splt_Pea&Hamsoup + 26.7 foods_Taco + 2.2 foods_Tofu
#  + 5.7 foods_Tomato,Red,Ripe,Raw + 33.2 foods_Tomato_Soup
#  + 17.8 foods_Tortilla_Chip + 20.4 foods_Vegetbeef_Soup
#  + 12.4 foods_Wheat_Bread + 11.8 foods_White_Bread + 22.3 foods_White_Rice
#  <= 450
#
# _C17: 3.7 foods_Apple,Raw,W_Skin + 0.5 foods_Apple_Pie + 0.6 foods_Bagels
#  + 2.7 foods_Banana + 8.6 foods_Beanbacn_Soup,W_Watr + 0.5 foods_Cap'N_Crunch
#  + 1.6 foods_Carrots,Raw + 0.7 foods_Celery,_Raw + 2 foods_Cheerios
#  + 1.5 foods_Chicknoodl_Soup + 0.7 foods_Corn_Flks,_Kellogg'S
#  + 1.3 foods_Couscous + 0.5 foods_Crm_Mshrm_Soup,W_Mlk
#  + 8.5 foods_Frozen_Broccoli + 2 foods_Frozen_Corn + 0.2 foods_Grapes
#  + 2.6 foods_Kiwifruit,Raw,Fresh + 0.3 foods_Lettuce,Iceberg,Raw
#  + 0.9 foods_Macaroni,Ckd + 1.5 foods_New_E_Clamchwd,W_Mlk
#  + 1.5 foods_Neweng_Clamchwd + 4 foods_Oatmeal + 0.6 foods_Oatmeal_Cookies
#  + 3.1 foods_Oranges + 2.1 foods_Peanut_Butter + 1.3 foods_Peppers,_Sweet,_Raw
#  + 4.3 foods_Popcorn,Air_Popped + 1.2 foods_Potato_Chips,Bbqflvr
#  + 3.2 foods_Potatoes,_Baked + 0.9 foods_Pretzels
#  + 4 foods_Raisin_Brn,_Kellg'S + 0.4 foods_Rice_Krispies
#  + 11.6 foods_Spaghetti_W__Sauce + 0.7 foods_Special_K
#  + 4.1 foods_Splt_Pea&Hamsoup + 1.4 foods_Tofu + 1.4 foods_Tomato,Red,Ripe,Raw
#  + foods_Tomato_Soup + 1.8 foods_Tortilla_Chip + 4 foods_Vegetbeef_Soup
#  + 1.3 foods_Wheat_Bread + 1.1 foods_White_Bread + 0.3 foods_White_Rice <= 250
#
# _C18: 8.1 foods_2%_Lowfat_Milk + 8 foods_3.3%_Fat,Whole_Milk
#  + 0.3 foods_Apple,Raw,W_Skin + 0.5 foods_Apple_Pie + 3 foods_Bagels
#  + 1.2 foods_Banana + 7.9 foods_Beanbacn_Soup,W_Watr
#  + 3.9 foods_Bologna,Turkey + 1.4 foods_Cap'N_Crunch + 0.6 foods_Carrots,Raw
#  + 0.3 foods_Celery,_Raw + 7 foods_Cheddar_Cheese + 4.3 foods_Cheerios
#  + 7.9 foods_Chicknoodl_Soup + 0.9 foods_Chocolate_Chip_Cookies
#  + 2.3 foods_Corn_Flks,_Kellogg'S + 3.4 foods_Couscous
#  + 6.1 foods_Crm_Mshrm_Soup,W_Mlk + 5.4 foods_Frankfurter,_Beef
#  + 8 foods_Frozen_Broccoli + 2.5 foods_Frozen_Corn + 0.2 foods_Grapes
#  + 5.5 foods_Ham,Sliced,Extralean + 13.6 foods_Hamburger_W_Toppings
#  + 10.4 foods_Hotdog,_Plain + 3.4 foods_Kielbasa,Prk
#  + 0.8 foods_Kiwifruit,Raw,Fresh + 0.2 foods_Lettuce,Iceberg,Raw
#  + 3.3 foods_Macaroni,Ckd + 17.3 foods_Malt_O_Meal,Choc
#  + 9.5 foods_New_E_Clamchwd,W_Mlk + 10.9 foods_Neweng_Clamchwd
#  + 6.1 foods_Oatmeal + 1.1 foods_Oatmeal_Cookies + 1.2 foods_Oranges
#  + 7.7 foods_Peanut_Butter + 0.7 foods_Peppers,_Sweet,_Raw
#  + 10.1 foods_Pizza_W_Pepperoni + 6.2 foods_Poached_Eggs
#  + 3.4 foods_Popcorn,Air_Popped + 13.8 foods_Pork
#  + 2.2 foods_Potato_Chips,Bbqflvr + 3.7 foods_Potatoes,_Baked
#  + 2.6 foods_Pretzels + 4 foods_Raisin_Brn,_Kellg'S + 1.9 foods_Rice_Krispies
#  + 42.2 foods_Roasted_Chicken + 5.9 foods_Sardines_in_Oil
#  + 6.7 foods_Scrambled_Eggs + 8.4 foods_Skim_Milk
#  + 8.2 foods_Spaghetti_W__Sauce + 5.6 foods_Special_K
#  + 11.1 foods_Splt_Pea&Hamsoup + 20.7 foods_Taco + 9.4 foods_Tofu
#  + foods_Tomato,Red,Ripe,Raw + 4.1 foods_Tomato_Soup + 2 foods_Tortilla_Chip
#  + 11.2 foods_Vegetbeef_Soup + 2.2 foods_Wheat_Bread + 2.3 foods_White_Bread
#  + 2.1 foods_White_Rice + 22.7 foods_White_Tuna_in_Water <= 100
#
# _C19: 500.2 foods_2%_Lowfat_Milk + 307.4 foods_3.3%_Fat,Whole_Milk
#  + 73.1 foods_Apple,Raw,W_Skin + 35.2 foods_Apple_Pie + 92.3 foods_Banana
#  + 888 foods_Beanbacn_Soup,W_Watr + 152.9 foods_Butter,Regular
#  + 40.6 foods_Cap'N_Crunch + 15471 foods_Carrots,Raw + 53.6 foods_Celery,_Raw
#  + 296.5 foods_Cheddar_Cheese + 1252.2 foods_Cheerios
#  + 1308.7 foods_Chicknoodl_Soup + 101.8 foods_Chocolate_Chip_Cookies
#  + 1252.2 foods_Corn_Flks,_Kellogg'S + 153.8 foods_Crm_Mshrm_Soup,W_Mlk
#  + 5867.4 foods_Frozen_Broccoli + 106.6 foods_Frozen_Corn + 24 foods_Grapes
#  + 126.3 foods_Hamburger_W_Toppings + 133 foods_Kiwifruit,Raw,Fresh
#  + 66 foods_Lettuce,Iceberg,Raw + 163.7 foods_New_E_Clamchwd,W_Mlk
#  + 20.1 foods_Neweng_Clamchwd + 37.4 foods_Oatmeal + 2.9 foods_Oatmeal_Cookies
#  + 268.6 foods_Oranges + 467.7 foods_Peppers,_Sweet,_Raw
#  + 281.9 foods_Pizza_W_Pepperoni + 316 foods_Poached_Eggs
#  + 55.6 foods_Popcorn,Air_Popped + 14.7 foods_Pork
#  + 61.5 foods_Potato_Chips,Bbqflvr + 1250.2 foods_Raisin_Brn,_Kellg'S
#  + 1252.2 foods_Rice_Krispies + 77.4 foods_Roasted_Chicken
#  + 53.8 foods_Sardines_in_Oil + 409.2 foods_Scrambled_Eggs
#  + 499.8 foods_Skim_Milk + 3055.2 foods_Spaghetti_W__Sauce
#  + 1252.2 foods_Special_K + 4872 foods_Splt_Pea&Hamsoup + 855 foods_Taco
#  + 98.6 foods_Tofu + 766.3 foods_Tomato,Red,Ripe,Raw + 1393 foods_Tomato_Soup
#  + 55.6 foods_Tortilla_Chip + 3785.1 foods_Vegetbeef_Soup
#  + 68 foods_White_Tuna_in_Water <= 10000
#
# _C20: 2.3 foods_2%_Lowfat_Milk + 2.3 foods_3.3%_Fat,Whole_Milk
#  + 7.9 foods_Apple,Raw,W_Skin + 0.9 foods_Apple_Pie + 10.4 foods_Banana
#  + 1.5 foods_Beanbacn_Soup,W_Watr + 5.1 foods_Carrots,Raw
#  + 2.8 foods_Celery,_Raw + 15.1 foods_Cheerios
#  + 15.1 foods_Corn_Flks,_Kellogg'S + 2.2 foods_Crm_Mshrm_Soup,W_Mlk
#  + 10.8 foods_Frankfurter,_Beef + 160.2 foods_Frozen_Broccoli
#  + 5.2 foods_Frozen_Corn + foods_Grapes + 7.4 foods_Ham,Sliced,Extralean
#  + 2.6 foods_Hamburger_W_Toppings + 0.1 foods_Hotdog,_Plain
#  + 5.5 foods_Kielbasa,Prk + 74.5 foods_Kiwifruit,Raw,Fresh
#  + 0.8 foods_Lettuce,Iceberg,Raw + 3.5 foods_New_E_Clamchwd,W_Mlk
#  + 4.8 foods_Neweng_Clamchwd + 0.1 foods_Oatmeal_Cookies + 69.7 foods_Oranges
#  + 66.1 foods_Peppers,_Sweet,_Raw + 1.6 foods_Pizza_W_Pepperoni
#  + 9.6 foods_Potato_Chips,Bbqflvr + 15.6 foods_Potatoes,_Baked
#  + 15.1 foods_Rice_Krispies + 0.1 foods_Scrambled_Eggs + 2.4 foods_Skim_Milk
#  + 27.9 foods_Spaghetti_W__Sauce + 15.1 foods_Special_K
#  + 7 foods_Splt_Pea&Hamsoup + 2.2 foods_Taco + 0.1 foods_Tofu
#  + 23.5 foods_Tomato,Red,Ripe,Raw + 133 foods_Tomato_Soup
#  + 4.8 foods_Vegetbeef_Soup <= 5000
#
# _C21: 296.7 foods_2%_Lowfat_Milk + 291.3 foods_3.3%_Fat,Whole_Milk
#  + 9.7 foods_Apple,Raw,W_Skin + 3.1 foods_Apple_Pie + 21 foods_Bagels
#  + 6.8 foods_Banana + 81 foods_Beanbacn_Soup,W_Watr
#  + 23.8 foods_Bologna,Turkey + 1.2 foods_Butter,Regular
#  + 4.8 foods_Cap'N_Crunch + 14.9 foods_Carrots,Raw + 16 foods_Celery,_Raw
#  + 202 foods_Cheddar_Cheese + 48.6 foods_Cheerios + 27.1 foods_Chicknoodl_Soup
#  + 6.2 foods_Chocolate_Chip_Cookies + 0.9 foods_Corn_Flks,_Kellogg'S
#  + 7.2 foods_Couscous + 178.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 9 foods_Frankfurter,_Beef + 159 foods_Frozen_Broccoli
#  + 3.3 foods_Frozen_Corn + 3.4 foods_Grapes + 2 foods_Ham,Sliced,Extralean
#  + 51.4 foods_Hamburger_W_Toppings + 23.5 foods_Hotdog,_Plain
#  + 11.4 foods_Kielbasa,Prk + 19.8 foods_Kiwifruit,Raw,Fresh
#  + 3.8 foods_Lettuce,Iceberg,Raw + 4.9 foods_Macaroni,Ckd
#  + 23.1 foods_Malt_O_Meal,Choc + 186 foods_New_E_Clamchwd,W_Mlk
#  + 82.8 foods_Neweng_Clamchwd + 18.7 foods_Oatmeal + 6.7 foods_Oatmeal_Cookies
#  + 52.4 foods_Oranges + 13.1 foods_Peanut_Butter
#  + 6.7 foods_Peppers,_Sweet,_Raw + 64.6 foods_Pizza_W_Pepperoni
#  + 24.5 foods_Poached_Eggs + 2.8 foods_Popcorn,Air_Popped + 59.9 foods_Pork
#  + 14.2 foods_Potato_Chips,Bbqflvr + 22.7 foods_Potatoes,_Baked
#  + 10.2 foods_Pretzels + 12.9 foods_Raisin_Brn,_Kellg'S
#  + 4 foods_Rice_Krispies + 21.9 foods_Roasted_Chicken
#  + 91.7 foods_Sardines_in_Oil + 42.6 foods_Scrambled_Eggs
#  + 302.3 foods_Skim_Milk + 80.2 foods_Spaghetti_W__Sauce + 8.2 foods_Special_K
#  + 33.6 foods_Splt_Pea&Hamsoup + 220.6 foods_Taco + 121.8 foods_Tofu
#  + 6.2 foods_Tomato,Red,Ripe,Raw + 27.6 foods_Tomato_Soup
#  + 43.7 foods_Tortilla_Chip + 32.6 foods_Vegetbeef_Soup
#  + 10.8 foods_Wheat_Bread + 26.2 foods_White_Bread + 7.9 foods_White_Rice
#  + 3.4 foods_White_Tuna_in_Water <= 1500
#
# _C22: 0.1 foods_2%_Lowfat_Milk + 0.1 foods_3.3%_Fat,Whole_Milk
#  + 0.2 foods_Apple,Raw,W_Skin + 0.1 foods_Apple_Pie + foods_Bagels
#  + 0.4 foods_Banana + 2 foods_Beanbacn_Soup,W_Watr + 0.4 foods_Bologna,Turkey
#  + 7.5 foods_Cap'N_Crunch + 0.3 foods_Carrots,Raw + 0.2 foods_Celery,_Raw
#  + 0.2 foods_Cheddar_Cheese + 4.5 foods_Cheerios + 1.5 foods_Chicknoodl_Soup
#  + 0.4 foods_Chocolate_Chip_Cookies + 1.8 foods_Corn_Flks,_Kellogg'S
#  + 0.3 foods_Couscous + 0.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 0.6 foods_Frankfurter,_Beef + 2.3 foods_Frozen_Broccoli
#  + 0.3 foods_Frozen_Corn + 0.1 foods_Grapes + 0.2 foods_Ham,Sliced,Extralean
#  + 2.5 foods_Hamburger_W_Toppings + 2.3 foods_Hotdog,_Plain
#  + 0.4 foods_Kielbasa,Prk + 0.3 foods_Kiwifruit,Raw,Fresh
#  + 0.1 foods_Lettuce,Iceberg,Raw + foods_Macaroni,Ckd
#  + 4.7 foods_Malt_O_Meal,Choc + 1.5 foods_New_E_Clamchwd,W_Mlk
#  + 2.8 foods_Neweng_Clamchwd + 1.6 foods_Oatmeal + 0.5 foods_Oatmeal_Cookies
#  + 0.1 foods_Oranges + 0.6 foods_Peanut_Butter + 0.3 foods_Peppers,_Sweet,_Raw
#  + 0.9 foods_Pizza_W_Pepperoni + 0.7 foods_Poached_Eggs
#  + 0.8 foods_Popcorn,Air_Popped + 0.4 foods_Pork
#  + 0.5 foods_Potato_Chips,Bbqflvr + 4.3 foods_Potatoes,_Baked
#  + 1.2 foods_Pretzels + 16.8 foods_Raisin_Brn,_Kellg'S
#  + 1.8 foods_Rice_Krispies + 1.8 foods_Roasted_Chicken
#  + 0.7 foods_Sardines_in_Oil + 0.7 foods_Scrambled_Eggs + 0.1 foods_Skim_Milk
#  + 2.3 foods_Spaghetti_W__Sauce + 4.5 foods_Special_K
#  + 2.1 foods_Splt_Pea&Hamsoup + 2.4 foods_Taco + 6.2 foods_Tofu
#  + 0.6 foods_Tomato,Red,Ripe,Raw + 3.5 foods_Tomato_Soup
#  + 0.4 foods_Tortilla_Chip + 2.2 foods_Vegetbeef_Soup + 0.7 foods_Wheat_Bread
#  + 0.8 foods_White_Bread + 0.9 foods_White_Rice
#  + 0.5 foods_White_Tuna_in_Water <= 40
#
# VARIABLES
# foods_2%_Lowfat_Milk Continuous
# foods_3.3%_Fat,Whole_Milk Continuous
# foods_Apple,Raw,W_Skin Continuous
# foods_Apple_Pie Continuous
# foods_Bagels Continuous
# foods_Banana Continuous
# foods_Beanbacn_Soup,W_Watr Continuous
# foods_Bologna,Turkey Continuous
# foods_Butter,Regular Continuous
# foods_Cap'N_Crunch Continuous
# foods_Carrots,Raw Continuous
# foods_Celery,_Raw Continuous
# foods_Cheddar_Cheese Continuous
# foods_Cheerios Continuous
# foods_Chicknoodl_Soup Continuous
# foods_Chocolate_Chip_Cookies Continuous
# foods_Corn_Flks,_Kellogg'S Continuous
# foods_Couscous Continuous
# foods_Crm_Mshrm_Soup,W_Mlk Continuous
# foods_Frankfurter,_Beef Continuous
# foods_Frozen_Broccoli Continuous
# foods_Frozen_Corn Continuous
# foods_Grapes Continuous
# foods_Ham,Sliced,Extralean Continuous
# foods_Hamburger_W_Toppings Continuous
# foods_Hotdog,_Plain Continuous
# foods_Kielbasa,Prk Continuous
# foods_Kiwifruit,Raw,Fresh Continuous
# foods_Lettuce,Iceberg,Raw Continuous
# foods_Macaroni,Ckd Continuous
# foods_Malt_O_Meal,Choc Continuous
# foods_New_E_Clamchwd,W_Mlk Continuous
# foods_Neweng_Clamchwd Continuous
# foods_Oatmeal Continuous
# foods_Oatmeal_Cookies Continuous
# foods_Oranges Continuous
# foods_Peanut_Butter Continuous
# foods_Peppers,_Sweet,_Raw Continuous
# foods_Pizza_W_Pepperoni Continuous
# foods_Poached_Eggs Continuous
# foods_Popcorn,Air_Popped Continuous
# foods_Pork Continuous
# foods_Potato_Chips,Bbqflvr Continuous
# foods_Potatoes,_Baked Continuous
# foods_Pretzels Continuous
# foods_Raisin_Brn,_Kellg'S Continuous
# foods_Rice_Krispies Continuous
# foods_Roasted_Chicken Continuous
# foods_Sardines_in_Oil Continuous
# foods_Scrambled_Eggs Continuous
# foods_Skim_Milk Continuous
# foods_Spaghetti_W__Sauce Continuous
# foods_Special_K Continuous
# foods_Splt_Pea&Hamsoup Continuous
# foods_Taco Continuous
# foods_Tofu Continuous
# foods_Tomato,Red,Ripe,Raw Continuous
# foods_Tomato_Soup Continuous
# foods_Tortilla_Chip Continuous
# foods_Vegetbeef_Soup Continuous
# foods_Wheat_Bread Continuous
# foods_White_Bread Continuous
# foods_White_Rice Continuous
# foods_White_Tuna_in_Water Continuous

# %%
# The status 1 meaning it has the optimal solution 
model1.solve()
# Out:
# 1

# %%
print('Optimization Solution:')
for v in model1.variables():
    if v.varValue > 0:
        if str(v).find('Chosen'):
            print(str(v.varValue) + " units of " + str(v))
# Out:
# Optimization Solution:
# 52.64371 units of foods_Celery,_Raw
# 0.25960653 units of foods_Frozen_Broccoli
# 63.988506 units of foods_Lettuce,Iceberg,Raw
# 2.2929389 units of foods_Oranges
# 0.14184397 units of foods_Poached_Eggs
# 13.869322 units of foods_Popcorn,Air_Popped

# %%
print("Total cost of food = $%.2f" % value(model1.objective))
# Out:
# Total cost of food = $4.34

# %% [markdown]
# ### Question 2

# %% [markdown]
# **2.	Please add to your model the following constraints (which might require adding more variables) and solve the new model:**<br><br>
# a.	If a food is selected, then a minimum of 1/10 serving must be chosen. (Hint: now you will need two variables for each food i: whether it is chosen, and how much is part of the diet. You’ll also need to write a constraint to link them.)<br>
# b.	Many people dislike celery and frozen broccoli. So at most one, but not both, can be selected.<br>
# c.	To get day-to-day variety in protein, at least 3 kinds of meat/poultry/fish/eggs must be selected. [If something is ambiguous (e.g., should bean-and-bacon soup be considered meat?), just call it whatever you think is appropriate – I want you to learn how to write this type of constraint, but I don’t really care whether we agree on how to classify foods!]

# %% [markdown]
# #### Step 1: Initializing and defining the second optimization model

# %%
## Initializing the problem class - minimizing 
model2 = LpProblem("Optimized_diet_problem2", LpMinimize)

# %%
## Defining the objective function 
model2 += lpSum(cost[j]*foods_var[j] for j in foods)

# %% [markdown]
# #### Step 2: Adding new constraints to the model

# %% [markdown]
# In this part, I added the new constraints: 1) the amount of food greater than 0.1 unit, 2) celery and frozen broccoli at most one not both, and 3) at least three kinds of meat/poultry/fish/eggs.

# %%
## Add constraint for the amount of food: should be greater than 0.1, less than 1000 (an arbitrary large number)
for j in foods: 
    model2 += foods_var[j] <= 1000 * choice_var[j]
    model2 += foods_var[j] >= 0.1 * choice_var[j]

# %%
## Add constraint for the amount of nutrients 

for i in range(0, 11): 
    B_x = pulp.lpSum([B[i][j] * foods_var[j] for j in foods]) # the total amount of nutrients intake 
    condition1 = min_take[i] <= + B_x
    model2 += condition1
    
for i in range(0, 11):
    B_x = pulp.lpSum([B[i][j] * foods_var[j] for j in foods]) # the total amount of nutrients intake 
    condition2 = max_take[i] >= + B_x
    model2 += condition2

# %%
## Add constraint for celery and frozen broccoli at most one, but not both

model2 += choice_var['Frozen Broccoli'] + choice_var['Celery, Raw'] <= 1

# %%
### Add constraint for at least 3 kinds of meat/poultry/fish/eggs

model2 += choice_var['Roasted Chicken'] + choice_var['Poached Eggs'] + choice_var['Scrambled Eggs'] + choice_var['Bologna,Turkey']+ choice_var['Frankfurter, Beef']+ choice_var['Ham,Sliced,Extralean']+ choice_var['Kielbasa,Prk']+ choice_var['Hamburger W/Toppings']+ choice_var['Hotdog, Plain']+ choice_var['Pork']+ choice_var['Sardines in Oil']+ choice_var['White Tuna in Water'] >= 3

# %% [markdown]
# #### Step 3: Solving the optimization problem

# %%
### review model 2
model2
# Out:
# Optimized_diet_problem2:
# MINIMIZE
# 0.23*foods_2%_Lowfat_Milk + 0.16*foods_3.3%_Fat,Whole_Milk + 0.24*foods_Apple,Raw,W_Skin + 0.16*foods_Apple_Pie + 0.16*foods_Bagels + 0.15*foods_Banana + 0.67*foods_Beanbacn_Soup,W_Watr + 0.15*foods_Bologna,Turkey + 0.05*foods_Butter,Regular + 0.31*foods_Cap'N_Crunch + 0.07*foods_Carrots,Raw + 0.04*foods_Celery,_Raw + 0.25*foods_Cheddar_Cheese + 0.28*foods_Cheerios + 0.39*foods_Chicknoodl_Soup + 0.03*foods_Chocolate_Chip_Cookies + 0.28*foods_Corn_Flks,_Kellogg'S + 0.39*foods_Couscous + 0.65*foods_Crm_Mshrm_Soup,W_Mlk + 0.27*foods_Frankfurter,_Beef + 0.16*foods_Frozen_Broccoli + 0.18*foods_Frozen_Corn + 0.32*foods_Grapes + 0.33*foods_Ham,Sliced,Extralean + 0.83*foods_Hamburger_W_Toppings + 0.31*foods_Hotdog,_Plain + 0.15*foods_Kielbasa,Prk + 0.49*foods_Kiwifruit,Raw,Fresh + 0.02*foods_Lettuce,Iceberg,Raw + 0.17*foods_Macaroni,Ckd + 0.52*foods_Malt_O_Meal,Choc + 0.99*foods_New_E_Clamchwd,W_Mlk + 0.75*foods_Neweng_Clamchwd + 0.82*foods_Oatmeal + 0.09*foods_Oatmeal_Cookies + 0.15*foods_Oranges + 0.07*foods_Peanut_Butter + 0.53*foods_Peppers,_Sweet,_Raw + 0.44*foods_Pizza_W_Pepperoni + 0.08*foods_Poached_Eggs + 0.04*foods_Popcorn,Air_Popped + 0.81*foods_Pork + 0.22*foods_Potato_Chips,Bbqflvr + 0.06*foods_Potatoes,_Baked + 0.12*foods_Pretzels + 0.34*foods_Raisin_Brn,_Kellg'S + 0.32*foods_Rice_Krispies + 0.84*foods_Roasted_Chicken + 0.45*foods_Sardines_in_Oil + 0.11*foods_Scrambled_Eggs + 0.13*foods_Skim_Milk + 0.78*foods_Spaghetti_W__Sauce + 0.38*foods_Special_K + 0.67*foods_Splt_Pea&Hamsoup + 0.59*foods_Taco + 0.31*foods_Tofu + 0.27*foods_Tomato,Red,Ripe,Raw + 0.39*foods_Tomato_Soup + 0.19*foods_Tortilla_Chip + 0.71*foods_Vegetbeef_Soup + 0.05*foods_Wheat_Bread + 0.06*foods_White_Bread + 0.08*foods_White_Rice + 0.69*foods_White_Tuna_in_Water + 0.0
# SUBJECT TO
# _C1: - 1000 chosen_Frozen_Broccoli + foods_Frozen_Broccoli <= 0
#
# _C2: - 0.1 chosen_Frozen_Broccoli + foods_Frozen_Broccoli >= 0
#
# _C3: - 1000 chosen_Carrots,Raw + foods_Carrots,Raw <= 0
#
# _C4: - 0.1 chosen_Carrots,Raw + foods_Carrots,Raw >= 0
#
# _C5: - 1000 chosen_Celery,_Raw + foods_Celery,_Raw <= 0
#
# _C6: - 0.1 chosen_Celery,_Raw + foods_Celery,_Raw >= 0
#
# _C7: - 1000 chosen_Frozen_Corn + foods_Frozen_Corn <= 0
#
# _C8: - 0.1 chosen_Frozen_Corn + foods_Frozen_Corn >= 0
#
# _C9: - 1000 chosen_Lettuce,Iceberg,Raw + foods_Lettuce,Iceberg,Raw <= 0
#
# _C10: - 0.1 chosen_Lettuce,Iceberg,Raw + foods_Lettuce,Iceberg,Raw >= 0
#
# _C11: - 1000 chosen_Peppers,_Sweet,_Raw + foods_Peppers,_Sweet,_Raw <= 0
#
# _C12: - 0.1 chosen_Peppers,_Sweet,_Raw + foods_Peppers,_Sweet,_Raw >= 0
#
# _C13: - 1000 chosen_Potatoes,_Baked + foods_Potatoes,_Baked <= 0
#
# _C14: - 0.1 chosen_Potatoes,_Baked + foods_Potatoes,_Baked >= 0
#
# _C15: - 1000 chosen_Tofu + foods_Tofu <= 0
#
# _C16: - 0.1 chosen_Tofu + foods_Tofu >= 0
#
# _C17: - 1000 chosen_Roasted_Chicken + foods_Roasted_Chicken <= 0
#
# _C18: - 0.1 chosen_Roasted_Chicken + foods_Roasted_Chicken >= 0
#
# _C19: - 1000 chosen_Spaghetti_W__Sauce + foods_Spaghetti_W__Sauce <= 0
#
# _C20: - 0.1 chosen_Spaghetti_W__Sauce + foods_Spaghetti_W__Sauce >= 0
#
# _C21: - 1000 chosen_Tomato,Red,Ripe,Raw + foods_Tomato,Red,Ripe,Raw <= 0
#
# _C22: - 0.1 chosen_Tomato,Red,Ripe,Raw + foods_Tomato,Red,Ripe,Raw >= 0
#
# _C23: - 1000 chosen_Apple,Raw,W_Skin + foods_Apple,Raw,W_Skin <= 0
#
# _C24: - 0.1 chosen_Apple,Raw,W_Skin + foods_Apple,Raw,W_Skin >= 0
#
# _C25: - 1000 chosen_Banana + foods_Banana <= 0
#
# _C26: - 0.1 chosen_Banana + foods_Banana >= 0
#
# _C27: - 1000 chosen_Grapes + foods_Grapes <= 0
#
# _C28: - 0.1 chosen_Grapes + foods_Grapes >= 0
#
# _C29: - 1000 chosen_Kiwifruit,Raw,Fresh + foods_Kiwifruit,Raw,Fresh <= 0
#
# _C30: - 0.1 chosen_Kiwifruit,Raw,Fresh + foods_Kiwifruit,Raw,Fresh >= 0
#
# _C31: - 1000 chosen_Oranges + foods_Oranges <= 0
#
# _C32: - 0.1 chosen_Oranges + foods_Oranges >= 0
#
# _C33: - 1000 chosen_Bagels + foods_Bagels <= 0
#
# _C34: - 0.1 chosen_Bagels + foods_Bagels >= 0
#
# _C35: - 1000 chosen_Wheat_Bread + foods_Wheat_Bread <= 0
#
# _C36: - 0.1 chosen_Wheat_Bread + foods_Wheat_Bread >= 0
#
# _C37: - 1000 chosen_White_Bread + foods_White_Bread <= 0
#
# _C38: - 0.1 chosen_White_Bread + foods_White_Bread >= 0
#
# _C39: - 1000 chosen_Oatmeal_Cookies + foods_Oatmeal_Cookies <= 0
#
# _C40: - 0.1 chosen_Oatmeal_Cookies + foods_Oatmeal_Cookies >= 0
#
# _C41: - 1000 chosen_Apple_Pie + foods_Apple_Pie <= 0
#
# _C42: - 0.1 chosen_Apple_Pie + foods_Apple_Pie >= 0
#
# _C43: - 1000 chosen_Chocolate_Chip_Cookies + foods_Chocolate_Chip_Cookies <= 0
#
# _C44: - 0.1 chosen_Chocolate_Chip_Cookies + foods_Chocolate_Chip_Cookies >= 0
#
# _C45: - 1000 chosen_Butter,Regular + foods_Butter,Regular <= 0
#
# _C46: - 0.1 chosen_Butter,Regular + foods_Butter,Regular >= 0
#
# _C47: - 1000 chosen_Cheddar_Cheese + foods_Cheddar_Cheese <= 0
#
# _C48: - 0.1 chosen_Cheddar_Cheese + foods_Cheddar_Cheese >= 0
#
# _C49: - 1000 chosen_3.3%_Fat,Whole_Milk + foods_3.3%_Fat,Whole_Milk <= 0
#
# _C50: - 0.1 chosen_3.3%_Fat,Whole_Milk + foods_3.3%_Fat,Whole_Milk >= 0
#
# _C51: - 1000 chosen_2%_Lowfat_Milk + foods_2%_Lowfat_Milk <= 0
#
# _C52: - 0.1 chosen_2%_Lowfat_Milk + foods_2%_Lowfat_Milk >= 0
#
# _C53: - 1000 chosen_Skim_Milk + foods_Skim_Milk <= 0
#
# _C54: - 0.1 chosen_Skim_Milk + foods_Skim_Milk >= 0
#
# _C55: - 1000 chosen_Poached_Eggs + foods_Poached_Eggs <= 0
#
# _C56: - 0.1 chosen_Poached_Eggs + foods_Poached_Eggs >= 0
#
# _C57: - 1000 chosen_Scrambled_Eggs + foods_Scrambled_Eggs <= 0
#
# _C58: - 0.1 chosen_Scrambled_Eggs + foods_Scrambled_Eggs >= 0
#
# _C59: - 1000 chosen_Bologna,Turkey + foods_Bologna,Turkey <= 0
#
# _C60: - 0.1 chosen_Bologna,Turkey + foods_Bologna,Turkey >= 0
#
# _C61: - 1000 chosen_Frankfurter,_Beef + foods_Frankfurter,_Beef <= 0
#
# _C62: - 0.1 chosen_Frankfurter,_Beef + foods_Frankfurter,_Beef >= 0
#
# _C63: - 1000 chosen_Ham,Sliced,Extralean + foods_Ham,Sliced,Extralean <= 0
#
# _C64: - 0.1 chosen_Ham,Sliced,Extralean + foods_Ham,Sliced,Extralean >= 0
#
# _C65: - 1000 chosen_Kielbasa,Prk + foods_Kielbasa,Prk <= 0
#
# _C66: - 0.1 chosen_Kielbasa,Prk + foods_Kielbasa,Prk >= 0
#
# _C67: - 1000 chosen_Cap'N_Crunch + foods_Cap'N_Crunch <= 0
#
# _C68: - 0.1 chosen_Cap'N_Crunch + foods_Cap'N_Crunch >= 0
#
# _C69: - 1000 chosen_Cheerios + foods_Cheerios <= 0
#
# _C70: - 0.1 chosen_Cheerios + foods_Cheerios >= 0
#
# _C71: - 1000 chosen_Corn_Flks,_Kellogg'S + foods_Corn_Flks,_Kellogg'S <= 0
#
# _C72: - 0.1 chosen_Corn_Flks,_Kellogg'S + foods_Corn_Flks,_Kellogg'S >= 0
#
# _C73: - 1000 chosen_Raisin_Brn,_Kellg'S + foods_Raisin_Brn,_Kellg'S <= 0
#
# _C74: - 0.1 chosen_Raisin_Brn,_Kellg'S + foods_Raisin_Brn,_Kellg'S >= 0
#
# _C75: - 1000 chosen_Rice_Krispies + foods_Rice_Krispies <= 0
#
# _C76: - 0.1 chosen_Rice_Krispies + foods_Rice_Krispies >= 0
#
# _C77: - 1000 chosen_Special_K + foods_Special_K <= 0
#
# _C78: - 0.1 chosen_Special_K + foods_Special_K >= 0
#
# _C79: - 1000 chosen_Oatmeal + foods_Oatmeal <= 0
#
# _C80: - 0.1 chosen_Oatmeal + foods_Oatmeal >= 0
#
# _C81: - 1000 chosen_Malt_O_Meal,Choc + foods_Malt_O_Meal,Choc <= 0
#
# _C82: - 0.1 chosen_Malt_O_Meal,Choc + foods_Malt_O_Meal,Choc >= 0
#
# _C83: - 1000 chosen_Pizza_W_Pepperoni + foods_Pizza_W_Pepperoni <= 0
#
# _C84: - 0.1 chosen_Pizza_W_Pepperoni + foods_Pizza_W_Pepperoni >= 0
#
# _C85: - 1000 chosen_Taco + foods_Taco <= 0
#
# _C86: - 0.1 chosen_Taco + foods_Taco >= 0
#
# _C87: - 1000 chosen_Hamburger_W_Toppings + foods_Hamburger_W_Toppings <= 0
#
# _C88: - 0.1 chosen_Hamburger_W_Toppings + foods_Hamburger_W_Toppings >= 0
#
# _C89: - 1000 chosen_Hotdog,_Plain + foods_Hotdog,_Plain <= 0
#
# _C90: - 0.1 chosen_Hotdog,_Plain + foods_Hotdog,_Plain >= 0
#
# _C91: - 1000 chosen_Couscous + foods_Couscous <= 0
#
# _C92: - 0.1 chosen_Couscous + foods_Couscous >= 0
#
# _C93: - 1000 chosen_White_Rice + foods_White_Rice <= 0
#
# _C94: - 0.1 chosen_White_Rice + foods_White_Rice >= 0
#
# _C95: - 1000 chosen_Macaroni,Ckd + foods_Macaroni,Ckd <= 0
#
# _C96: - 0.1 chosen_Macaroni,Ckd + foods_Macaroni,Ckd >= 0
#
# _C97: - 1000 chosen_Peanut_Butter + foods_Peanut_Butter <= 0
#
# _C98: - 0.1 chosen_Peanut_Butter + foods_Peanut_Butter >= 0
#
# _C99: - 1000 chosen_Pork + foods_Pork <= 0
#
# _C100: - 0.1 chosen_Pork + foods_Pork >= 0
#
# _C101: - 1000 chosen_Sardines_in_Oil + foods_Sardines_in_Oil <= 0
#
# _C102: - 0.1 chosen_Sardines_in_Oil + foods_Sardines_in_Oil >= 0
#
# _C103: - 1000 chosen_White_Tuna_in_Water + foods_White_Tuna_in_Water <= 0
#
# _C104: - 0.1 chosen_White_Tuna_in_Water + foods_White_Tuna_in_Water >= 0
#
# _C105: - 1000 chosen_Popcorn,Air_Popped + foods_Popcorn,Air_Popped <= 0
#
# _C106: - 0.1 chosen_Popcorn,Air_Popped + foods_Popcorn,Air_Popped >= 0
#
# _C107: - 1000 chosen_Potato_Chips,Bbqflvr + foods_Potato_Chips,Bbqflvr <= 0
#
# _C108: - 0.1 chosen_Potato_Chips,Bbqflvr + foods_Potato_Chips,Bbqflvr >= 0
#
# _C109: - 1000 chosen_Pretzels + foods_Pretzels <= 0
#
# _C110: - 0.1 chosen_Pretzels + foods_Pretzels >= 0
#
# _C111: - 1000 chosen_Tortilla_Chip + foods_Tortilla_Chip <= 0
#
# _C112: - 0.1 chosen_Tortilla_Chip + foods_Tortilla_Chip >= 0
#
# _C113: - 1000 chosen_Chicknoodl_Soup + foods_Chicknoodl_Soup <= 0
#
# _C114: - 0.1 chosen_Chicknoodl_Soup + foods_Chicknoodl_Soup >= 0
#
# _C115: - 1000 chosen_Splt_Pea&Hamsoup + foods_Splt_Pea&Hamsoup <= 0
#
# _C116: - 0.1 chosen_Splt_Pea&Hamsoup + foods_Splt_Pea&Hamsoup >= 0
#
# _C117: - 1000 chosen_Vegetbeef_Soup + foods_Vegetbeef_Soup <= 0
#
# _C118: - 0.1 chosen_Vegetbeef_Soup + foods_Vegetbeef_Soup >= 0
#
# _C119: - 1000 chosen_Neweng_Clamchwd + foods_Neweng_Clamchwd <= 0
#
# _C120: - 0.1 chosen_Neweng_Clamchwd + foods_Neweng_Clamchwd >= 0
#
# _C121: - 1000 chosen_Tomato_Soup + foods_Tomato_Soup <= 0
#
# _C122: - 0.1 chosen_Tomato_Soup + foods_Tomato_Soup >= 0
#
# _C123: - 1000 chosen_New_E_Clamchwd,W_Mlk + foods_New_E_Clamchwd,W_Mlk <= 0
#
# _C124: - 0.1 chosen_New_E_Clamchwd,W_Mlk + foods_New_E_Clamchwd,W_Mlk >= 0
#
# _C125: - 1000 chosen_Crm_Mshrm_Soup,W_Mlk + foods_Crm_Mshrm_Soup,W_Mlk <= 0
#
# _C126: - 0.1 chosen_Crm_Mshrm_Soup,W_Mlk + foods_Crm_Mshrm_Soup,W_Mlk >= 0
#
# _C127: - 1000 chosen_Beanbacn_Soup,W_Watr + foods_Beanbacn_Soup,W_Watr <= 0
#
# _C128: - 0.1 chosen_Beanbacn_Soup,W_Watr + foods_Beanbacn_Soup,W_Watr >= 0
#
# _C129: 121.2 foods_2%_Lowfat_Milk + 149.9 foods_3.3%_Fat,Whole_Milk
#  + 81.4 foods_Apple,Raw,W_Skin + 67.2 foods_Apple_Pie + 78 foods_Bagels
#  + 104.9 foods_Banana + 172 foods_Beanbacn_Soup,W_Watr
#  + 56.4 foods_Bologna,Turkey + 35.8 foods_Butter,Regular
#  + 119.6 foods_Cap'N_Crunch + 23.7 foods_Carrots,Raw + 6.4 foods_Celery,_Raw
#  + 112.7 foods_Cheddar_Cheese + 111 foods_Cheerios
#  + 150.1 foods_Chicknoodl_Soup + 78.1 foods_Chocolate_Chip_Cookies
#  + 110.5 foods_Corn_Flks,_Kellogg'S + 100.8 foods_Couscous
#  + 203.4 foods_Crm_Mshrm_Soup,W_Mlk + 141.8 foods_Frankfurter,_Beef
#  + 73.8 foods_Frozen_Broccoli + 72.2 foods_Frozen_Corn + 15.1 foods_Grapes
#  + 37.1 foods_Ham,Sliced,Extralean + 275 foods_Hamburger_W_Toppings
#  + 242.1 foods_Hotdog,_Plain + 80.6 foods_Kielbasa,Prk
#  + 46.4 foods_Kiwifruit,Raw,Fresh + 2.6 foods_Lettuce,Iceberg,Raw
#  + 98.7 foods_Macaroni,Ckd + 607.2 foods_Malt_O_Meal,Choc
#  + 163.7 foods_New_E_Clamchwd,W_Mlk + 175.7 foods_Neweng_Clamchwd
#  + 145.1 foods_Oatmeal + 81 foods_Oatmeal_Cookies + 61.6 foods_Oranges
#  + 188.5 foods_Peanut_Butter + 20 foods_Peppers,_Sweet,_Raw
#  + 181 foods_Pizza_W_Pepperoni + 74.5 foods_Poached_Eggs
#  + 108.3 foods_Popcorn,Air_Popped + 710.8 foods_Pork
#  + 139.2 foods_Potato_Chips,Bbqflvr + 171.5 foods_Potatoes,_Baked
#  + 108 foods_Pretzels + 115.1 foods_Raisin_Brn,_Kellg'S
#  + 112.2 foods_Rice_Krispies + 277.4 foods_Roasted_Chicken
#  + 49.9 foods_Sardines_in_Oil + 99.6 foods_Scrambled_Eggs
#  + 85.5 foods_Skim_Milk + 358.2 foods_Spaghetti_W__Sauce
#  + 110.8 foods_Special_K + 184.8 foods_Splt_Pea&Hamsoup + 369.4 foods_Taco
#  + 88.2 foods_Tofu + 25.8 foods_Tomato,Red,Ripe,Raw + 170.7 foods_Tomato_Soup
#  + 142 foods_Tortilla_Chip + 158.1 foods_Vegetbeef_Soup + 65 foods_Wheat_Bread
#  + 65 foods_White_Bread + 102.7 foods_White_Rice
#  + 115.6 foods_White_Tuna_in_Water >= 1500
#
# _C130: 18.3 foods_2%_Lowfat_Milk + 33.2 foods_3.3%_Fat,Whole_Milk
#  + 2.5 foods_Beanbacn_Soup,W_Watr + 28.1 foods_Bologna,Turkey
#  + 10.9 foods_Butter,Regular + 29.4 foods_Cheddar_Cheese
#  + 12.3 foods_Chicknoodl_Soup + 5.1 foods_Chocolate_Chip_Cookies
#  + 19.8 foods_Crm_Mshrm_Soup,W_Mlk + 27.4 foods_Frankfurter,_Beef
#  + 13.3 foods_Ham,Sliced,Extralean + 42.8 foods_Hamburger_W_Toppings
#  + 44.1 foods_Hotdog,_Plain + 17.4 foods_Kielbasa,Prk
#  + 22.3 foods_New_E_Clamchwd,W_Mlk + 10 foods_Neweng_Clamchwd
#  + 14.2 foods_Pizza_W_Pepperoni + 211.5 foods_Poached_Eggs + 105.1 foods_Pork
#  + 129.9 foods_Roasted_Chicken + 34.1 foods_Sardines_in_Oil
#  + 211.2 foods_Scrambled_Eggs + 4.4 foods_Skim_Milk
#  + 7.2 foods_Splt_Pea&Hamsoup + 56.4 foods_Taco + 10 foods_Vegetbeef_Soup
#  + 35.7 foods_White_Tuna_in_Water >= 30
#
# _C131: 4.7 foods_2%_Lowfat_Milk + 8.1 foods_3.3%_Fat,Whole_Milk
#  + 0.5 foods_Apple,Raw,W_Skin + 3.1 foods_Apple_Pie + 0.5 foods_Bagels
#  + 0.5 foods_Banana + 5.9 foods_Beanbacn_Soup,W_Watr
#  + 4.3 foods_Bologna,Turkey + 4.1 foods_Butter,Regular
#  + 2.6 foods_Cap'N_Crunch + 0.1 foods_Carrots,Raw + 0.1 foods_Celery,_Raw
#  + 9.3 foods_Cheddar_Cheese + 1.8 foods_Cheerios + 4.6 foods_Chicknoodl_Soup
#  + 4.5 foods_Chocolate_Chip_Cookies + 0.1 foods_Corn_Flks,_Kellogg'S
#  + 0.1 foods_Couscous + 13.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 12.8 foods_Frankfurter,_Beef + 0.8 foods_Frozen_Broccoli
#  + 0.6 foods_Frozen_Corn + 0.1 foods_Grapes + 1.4 foods_Ham,Sliced,Extralean
#  + 10.2 foods_Hamburger_W_Toppings + 14.5 foods_Hotdog,_Plain
#  + 7.1 foods_Kielbasa,Prk + 0.3 foods_Kiwifruit,Raw,Fresh
#  + 0.5 foods_Macaroni,Ckd + 1.5 foods_Malt_O_Meal,Choc
#  + 6.6 foods_New_E_Clamchwd,W_Mlk + 5 foods_Neweng_Clamchwd
#  + 2.3 foods_Oatmeal + 3.3 foods_Oatmeal_Cookies + 0.2 foods_Oranges
#  + 16 foods_Peanut_Butter + 0.1 foods_Peppers,_Sweet,_Raw
#  + 7 foods_Pizza_W_Pepperoni + 5 foods_Poached_Eggs
#  + 1.2 foods_Popcorn,Air_Popped + 72.2 foods_Pork
#  + 9.2 foods_Potato_Chips,Bbqflvr + 0.2 foods_Potatoes,_Baked + foods_Pretzels
#  + 0.7 foods_Raisin_Brn,_Kellg'S + 0.2 foods_Rice_Krispies
#  + 10.8 foods_Roasted_Chicken + 2.7 foods_Sardines_in_Oil
#  + 7.3 foods_Scrambled_Eggs + 0.4 foods_Skim_Milk
#  + 12.3 foods_Spaghetti_W__Sauce + 0.1 foods_Special_K
#  + 4 foods_Splt_Pea&Hamsoup + 20.6 foods_Taco + 5.5 foods_Tofu
#  + 0.4 foods_Tomato,Red,Ripe,Raw + 3.8 foods_Tomato_Soup
#  + 7.4 foods_Tortilla_Chip + 3.8 foods_Vegetbeef_Soup + foods_Wheat_Bread
#  + foods_White_Bread + 0.2 foods_White_Rice + 2.1 foods_White_Tuna_in_Water
#  >= 20
#
# _C132: 121.8 foods_2%_Lowfat_Milk + 119.6 foods_3.3%_Fat,Whole_Milk
#  + 75.4 foods_Apple_Pie + 151.4 foods_Bagels + 1.1 foods_Banana
#  + 951.3 foods_Beanbacn_Soup,W_Watr + 248.9 foods_Bologna,Turkey
#  + 41.3 foods_Butter,Regular + 213.3 foods_Cap'N_Crunch
#  + 19.2 foods_Carrots,Raw + 34.8 foods_Celery,_Raw
#  + 173.7 foods_Cheddar_Cheese + 307.6 foods_Cheerios
#  + 1862.2 foods_Chicknoodl_Soup + 57.8 foods_Chocolate_Chip_Cookies
#  + 290.5 foods_Corn_Flks,_Kellogg'S + 4.5 foods_Couscous
#  + 1076.3 foods_Crm_Mshrm_Soup,W_Mlk + 461.7 foods_Frankfurter,_Beef
#  + 68.2 foods_Frozen_Broccoli + 2.5 foods_Frozen_Corn + 0.5 foods_Grapes
#  + 405.1 foods_Ham,Sliced,Extralean + 563.9 foods_Hamburger_W_Toppings
#  + 670.3 foods_Hotdog,_Plain + 279.8 foods_Kielbasa,Prk
#  + 3.8 foods_Kiwifruit,Raw,Fresh + 1.8 foods_Lettuce,Iceberg,Raw
#  + 0.7 foods_Macaroni,Ckd + 16.5 foods_Malt_O_Meal,Choc
#  + 992 foods_New_E_Clamchwd,W_Mlk + 1864.9 foods_Neweng_Clamchwd
#  + 2.3 foods_Oatmeal + 68.9 foods_Oatmeal_Cookies + 155.5 foods_Peanut_Butter
#  + 1.5 foods_Peppers,_Sweet,_Raw + 267 foods_Pizza_W_Pepperoni
#  + 140 foods_Poached_Eggs + 1.1 foods_Popcorn,Air_Popped + 38.4 foods_Pork
#  + 212.6 foods_Potato_Chips,Bbqflvr + 15.2 foods_Potatoes,_Baked
#  + 486.2 foods_Pretzels + 204.4 foods_Raisin_Brn,_Kellg'S
#  + 340.8 foods_Rice_Krispies + 125.6 foods_Roasted_Chicken
#  + 121.2 foods_Sardines_in_Oil + 168 foods_Scrambled_Eggs
#  + 126.2 foods_Skim_Milk + 1237.1 foods_Spaghetti_W__Sauce
#  + 265.5 foods_Special_K + 964.8 foods_Splt_Pea&Hamsoup + 802 foods_Taco
#  + 8.1 foods_Tofu + 11.1 foods_Tomato,Red,Ripe,Raw + 1744.4 foods_Tomato_Soup
#  + 149.7 foods_Tortilla_Chip + 1915.1 foods_Vegetbeef_Soup
#  + 134.5 foods_Wheat_Bread + 132.5 foods_White_Bread + 0.8 foods_White_Rice
#  + 333.2 foods_White_Tuna_in_Water >= 800
#
# _C133: 11.7 foods_2%_Lowfat_Milk + 11.4 foods_3.3%_Fat,Whole_Milk
#  + 21 foods_Apple,Raw,W_Skin + 9.6 foods_Apple_Pie + 15.1 foods_Bagels
#  + 26.7 foods_Banana + 22.8 foods_Beanbacn_Soup,W_Watr
#  + 0.3 foods_Bologna,Turkey + 23 foods_Cap'N_Crunch + 5.6 foods_Carrots,Raw
#  + 1.5 foods_Celery,_Raw + 0.4 foods_Cheddar_Cheese + 19.6 foods_Cheerios
#  + 18.7 foods_Chicknoodl_Soup + 9.3 foods_Chocolate_Chip_Cookies
#  + 24.5 foods_Corn_Flks,_Kellogg'S + 20.9 foods_Couscous
#  + 15 foods_Crm_Mshrm_Soup,W_Mlk + 0.8 foods_Frankfurter,_Beef
#  + 13.6 foods_Frozen_Broccoli + 17.1 foods_Frozen_Corn + 4.1 foods_Grapes
#  + 0.3 foods_Ham,Sliced,Extralean + 32.7 foods_Hamburger_W_Toppings
#  + 18 foods_Hotdog,_Plain + 0.6 foods_Kielbasa,Prk
#  + 11.3 foods_Kiwifruit,Raw,Fresh + 0.4 foods_Lettuce,Iceberg,Raw
#  + 19.8 foods_Macaroni,Ckd + 128.2 foods_Malt_O_Meal,Choc
#  + 16.6 foods_New_E_Clamchwd,W_Mlk + 21.8 foods_Neweng_Clamchwd
#  + 25.3 foods_Oatmeal + 12.4 foods_Oatmeal_Cookies + 15.4 foods_Oranges
#  + 6.9 foods_Peanut_Butter + 4.8 foods_Peppers,_Sweet,_Raw
#  + 19.9 foods_Pizza_W_Pepperoni + 0.6 foods_Poached_Eggs
#  + 22.1 foods_Popcorn,Air_Popped + 15 foods_Potato_Chips,Bbqflvr
#  + 39.9 foods_Potatoes,_Baked + 22.5 foods_Pretzels
#  + 27.9 foods_Raisin_Brn,_Kellg'S + 24.8 foods_Rice_Krispies
#  + 1.3 foods_Scrambled_Eggs + 11.9 foods_Skim_Milk
#  + 58.3 foods_Spaghetti_W__Sauce + 21.3 foods_Special_K
#  + 26.8 foods_Splt_Pea&Hamsoup + 26.7 foods_Taco + 2.2 foods_Tofu
#  + 5.7 foods_Tomato,Red,Ripe,Raw + 33.2 foods_Tomato_Soup
#  + 17.8 foods_Tortilla_Chip + 20.4 foods_Vegetbeef_Soup
#  + 12.4 foods_Wheat_Bread + 11.8 foods_White_Bread + 22.3 foods_White_Rice
#  >= 130
#
# _C134: 3.7 foods_Apple,Raw,W_Skin + 0.5 foods_Apple_Pie + 0.6 foods_Bagels
#  + 2.7 foods_Banana + 8.6 foods_Beanbacn_Soup,W_Watr + 0.5 foods_Cap'N_Crunch
#  + 1.6 foods_Carrots,Raw + 0.7 foods_Celery,_Raw + 2 foods_Cheerios
#  + 1.5 foods_Chicknoodl_Soup + 0.7 foods_Corn_Flks,_Kellogg'S
#  + 1.3 foods_Couscous + 0.5 foods_Crm_Mshrm_Soup,W_Mlk
#  + 8.5 foods_Frozen_Broccoli + 2 foods_Frozen_Corn + 0.2 foods_Grapes
#  + 2.6 foods_Kiwifruit,Raw,Fresh + 0.3 foods_Lettuce,Iceberg,Raw
#  + 0.9 foods_Macaroni,Ckd + 1.5 foods_New_E_Clamchwd,W_Mlk
#  + 1.5 foods_Neweng_Clamchwd + 4 foods_Oatmeal + 0.6 foods_Oatmeal_Cookies
#  + 3.1 foods_Oranges + 2.1 foods_Peanut_Butter + 1.3 foods_Peppers,_Sweet,_Raw
#  + 4.3 foods_Popcorn,Air_Popped + 1.2 foods_Potato_Chips,Bbqflvr
#  + 3.2 foods_Potatoes,_Baked + 0.9 foods_Pretzels
#  + 4 foods_Raisin_Brn,_Kellg'S + 0.4 foods_Rice_Krispies
#  + 11.6 foods_Spaghetti_W__Sauce + 0.7 foods_Special_K
#  + 4.1 foods_Splt_Pea&Hamsoup + 1.4 foods_Tofu + 1.4 foods_Tomato,Red,Ripe,Raw
#  + foods_Tomato_Soup + 1.8 foods_Tortilla_Chip + 4 foods_Vegetbeef_Soup
#  + 1.3 foods_Wheat_Bread + 1.1 foods_White_Bread + 0.3 foods_White_Rice >= 125
#
# _C135: 8.1 foods_2%_Lowfat_Milk + 8 foods_3.3%_Fat,Whole_Milk
#  + 0.3 foods_Apple,Raw,W_Skin + 0.5 foods_Apple_Pie + 3 foods_Bagels
#  + 1.2 foods_Banana + 7.9 foods_Beanbacn_Soup,W_Watr
#  + 3.9 foods_Bologna,Turkey + 1.4 foods_Cap'N_Crunch + 0.6 foods_Carrots,Raw
#  + 0.3 foods_Celery,_Raw + 7 foods_Cheddar_Cheese + 4.3 foods_Cheerios
#  + 7.9 foods_Chicknoodl_Soup + 0.9 foods_Chocolate_Chip_Cookies
#  + 2.3 foods_Corn_Flks,_Kellogg'S + 3.4 foods_Couscous
#  + 6.1 foods_Crm_Mshrm_Soup,W_Mlk + 5.4 foods_Frankfurter,_Beef
#  + 8 foods_Frozen_Broccoli + 2.5 foods_Frozen_Corn + 0.2 foods_Grapes
#  + 5.5 foods_Ham,Sliced,Extralean + 13.6 foods_Hamburger_W_Toppings
#  + 10.4 foods_Hotdog,_Plain + 3.4 foods_Kielbasa,Prk
#  + 0.8 foods_Kiwifruit,Raw,Fresh + 0.2 foods_Lettuce,Iceberg,Raw
#  + 3.3 foods_Macaroni,Ckd + 17.3 foods_Malt_O_Meal,Choc
#  + 9.5 foods_New_E_Clamchwd,W_Mlk + 10.9 foods_Neweng_Clamchwd
#  + 6.1 foods_Oatmeal + 1.1 foods_Oatmeal_Cookies + 1.2 foods_Oranges
#  + 7.7 foods_Peanut_Butter + 0.7 foods_Peppers,_Sweet,_Raw
#  + 10.1 foods_Pizza_W_Pepperoni + 6.2 foods_Poached_Eggs
#  + 3.4 foods_Popcorn,Air_Popped + 13.8 foods_Pork
#  + 2.2 foods_Potato_Chips,Bbqflvr + 3.7 foods_Potatoes,_Baked
#  + 2.6 foods_Pretzels + 4 foods_Raisin_Brn,_Kellg'S + 1.9 foods_Rice_Krispies
#  + 42.2 foods_Roasted_Chicken + 5.9 foods_Sardines_in_Oil
#  + 6.7 foods_Scrambled_Eggs + 8.4 foods_Skim_Milk
#  + 8.2 foods_Spaghetti_W__Sauce + 5.6 foods_Special_K
#  + 11.1 foods_Splt_Pea&Hamsoup + 20.7 foods_Taco + 9.4 foods_Tofu
#  + foods_Tomato,Red,Ripe,Raw + 4.1 foods_Tomato_Soup + 2 foods_Tortilla_Chip
#  + 11.2 foods_Vegetbeef_Soup + 2.2 foods_Wheat_Bread + 2.3 foods_White_Bread
#  + 2.1 foods_White_Rice + 22.7 foods_White_Tuna_in_Water >= 60
#
# _C136: 500.2 foods_2%_Lowfat_Milk + 307.4 foods_3.3%_Fat,Whole_Milk
#  + 73.1 foods_Apple,Raw,W_Skin + 35.2 foods_Apple_Pie + 92.3 foods_Banana
#  + 888 foods_Beanbacn_Soup,W_Watr + 152.9 foods_Butter,Regular
#  + 40.6 foods_Cap'N_Crunch + 15471 foods_Carrots,Raw + 53.6 foods_Celery,_Raw
#  + 296.5 foods_Cheddar_Cheese + 1252.2 foods_Cheerios
#  + 1308.7 foods_Chicknoodl_Soup + 101.8 foods_Chocolate_Chip_Cookies
#  + 1252.2 foods_Corn_Flks,_Kellogg'S + 153.8 foods_Crm_Mshrm_Soup,W_Mlk
#  + 5867.4 foods_Frozen_Broccoli + 106.6 foods_Frozen_Corn + 24 foods_Grapes
#  + 126.3 foods_Hamburger_W_Toppings + 133 foods_Kiwifruit,Raw,Fresh
#  + 66 foods_Lettuce,Iceberg,Raw + 163.7 foods_New_E_Clamchwd,W_Mlk
#  + 20.1 foods_Neweng_Clamchwd + 37.4 foods_Oatmeal + 2.9 foods_Oatmeal_Cookies
#  + 268.6 foods_Oranges + 467.7 foods_Peppers,_Sweet,_Raw
#  + 281.9 foods_Pizza_W_Pepperoni + 316 foods_Poached_Eggs
#  + 55.6 foods_Popcorn,Air_Popped + 14.7 foods_Pork
#  + 61.5 foods_Potato_Chips,Bbqflvr + 1250.2 foods_Raisin_Brn,_Kellg'S
#  + 1252.2 foods_Rice_Krispies + 77.4 foods_Roasted_Chicken
#  + 53.8 foods_Sardines_in_Oil + 409.2 foods_Scrambled_Eggs
#  + 499.8 foods_Skim_Milk + 3055.2 foods_Spaghetti_W__Sauce
#  + 1252.2 foods_Special_K + 4872 foods_Splt_Pea&Hamsoup + 855 foods_Taco
#  + 98.6 foods_Tofu + 766.3 foods_Tomato,Red,Ripe,Raw + 1393 foods_Tomato_Soup
#  + 55.6 foods_Tortilla_Chip + 3785.1 foods_Vegetbeef_Soup
#  + 68 foods_White_Tuna_in_Water >= 1000
#
# _C137: 2.3 foods_2%_Lowfat_Milk + 2.3 foods_3.3%_Fat,Whole_Milk
#  + 7.9 foods_Apple,Raw,W_Skin + 0.9 foods_Apple_Pie + 10.4 foods_Banana
#  + 1.5 foods_Beanbacn_Soup,W_Watr + 5.1 foods_Carrots,Raw
#  + 2.8 foods_Celery,_Raw + 15.1 foods_Cheerios
#  + 15.1 foods_Corn_Flks,_Kellogg'S + 2.2 foods_Crm_Mshrm_Soup,W_Mlk
#  + 10.8 foods_Frankfurter,_Beef + 160.2 foods_Frozen_Broccoli
#  + 5.2 foods_Frozen_Corn + foods_Grapes + 7.4 foods_Ham,Sliced,Extralean
#  + 2.6 foods_Hamburger_W_Toppings + 0.1 foods_Hotdog,_Plain
#  + 5.5 foods_Kielbasa,Prk + 74.5 foods_Kiwifruit,Raw,Fresh
#  + 0.8 foods_Lettuce,Iceberg,Raw + 3.5 foods_New_E_Clamchwd,W_Mlk
#  + 4.8 foods_Neweng_Clamchwd + 0.1 foods_Oatmeal_Cookies + 69.7 foods_Oranges
#  + 66.1 foods_Peppers,_Sweet,_Raw + 1.6 foods_Pizza_W_Pepperoni
#  + 9.6 foods_Potato_Chips,Bbqflvr + 15.6 foods_Potatoes,_Baked
#  + 15.1 foods_Rice_Krispies + 0.1 foods_Scrambled_Eggs + 2.4 foods_Skim_Milk
#  + 27.9 foods_Spaghetti_W__Sauce + 15.1 foods_Special_K
#  + 7 foods_Splt_Pea&Hamsoup + 2.2 foods_Taco + 0.1 foods_Tofu
#  + 23.5 foods_Tomato,Red,Ripe,Raw + 133 foods_Tomato_Soup
#  + 4.8 foods_Vegetbeef_Soup >= 400
#
# _C138: 296.7 foods_2%_Lowfat_Milk + 291.3 foods_3.3%_Fat,Whole_Milk
#  + 9.7 foods_Apple,Raw,W_Skin + 3.1 foods_Apple_Pie + 21 foods_Bagels
#  + 6.8 foods_Banana + 81 foods_Beanbacn_Soup,W_Watr
#  + 23.8 foods_Bologna,Turkey + 1.2 foods_Butter,Regular
#  + 4.8 foods_Cap'N_Crunch + 14.9 foods_Carrots,Raw + 16 foods_Celery,_Raw
#  + 202 foods_Cheddar_Cheese + 48.6 foods_Cheerios + 27.1 foods_Chicknoodl_Soup
#  + 6.2 foods_Chocolate_Chip_Cookies + 0.9 foods_Corn_Flks,_Kellogg'S
#  + 7.2 foods_Couscous + 178.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 9 foods_Frankfurter,_Beef + 159 foods_Frozen_Broccoli
#  + 3.3 foods_Frozen_Corn + 3.4 foods_Grapes + 2 foods_Ham,Sliced,Extralean
#  + 51.4 foods_Hamburger_W_Toppings + 23.5 foods_Hotdog,_Plain
#  + 11.4 foods_Kielbasa,Prk + 19.8 foods_Kiwifruit,Raw,Fresh
#  + 3.8 foods_Lettuce,Iceberg,Raw + 4.9 foods_Macaroni,Ckd
#  + 23.1 foods_Malt_O_Meal,Choc + 186 foods_New_E_Clamchwd,W_Mlk
#  + 82.8 foods_Neweng_Clamchwd + 18.7 foods_Oatmeal + 6.7 foods_Oatmeal_Cookies
#  + 52.4 foods_Oranges + 13.1 foods_Peanut_Butter
#  + 6.7 foods_Peppers,_Sweet,_Raw + 64.6 foods_Pizza_W_Pepperoni
#  + 24.5 foods_Poached_Eggs + 2.8 foods_Popcorn,Air_Popped + 59.9 foods_Pork
#  + 14.2 foods_Potato_Chips,Bbqflvr + 22.7 foods_Potatoes,_Baked
#  + 10.2 foods_Pretzels + 12.9 foods_Raisin_Brn,_Kellg'S
#  + 4 foods_Rice_Krispies + 21.9 foods_Roasted_Chicken
#  + 91.7 foods_Sardines_in_Oil + 42.6 foods_Scrambled_Eggs
#  + 302.3 foods_Skim_Milk + 80.2 foods_Spaghetti_W__Sauce + 8.2 foods_Special_K
#  + 33.6 foods_Splt_Pea&Hamsoup + 220.6 foods_Taco + 121.8 foods_Tofu
#  + 6.2 foods_Tomato,Red,Ripe,Raw + 27.6 foods_Tomato_Soup
#  + 43.7 foods_Tortilla_Chip + 32.6 foods_Vegetbeef_Soup
#  + 10.8 foods_Wheat_Bread + 26.2 foods_White_Bread + 7.9 foods_White_Rice
#  + 3.4 foods_White_Tuna_in_Water >= 700
#
# _C139: 0.1 foods_2%_Lowfat_Milk + 0.1 foods_3.3%_Fat,Whole_Milk
#  + 0.2 foods_Apple,Raw,W_Skin + 0.1 foods_Apple_Pie + foods_Bagels
#  + 0.4 foods_Banana + 2 foods_Beanbacn_Soup,W_Watr + 0.4 foods_Bologna,Turkey
#  + 7.5 foods_Cap'N_Crunch + 0.3 foods_Carrots,Raw + 0.2 foods_Celery,_Raw
#  + 0.2 foods_Cheddar_Cheese + 4.5 foods_Cheerios + 1.5 foods_Chicknoodl_Soup
#  + 0.4 foods_Chocolate_Chip_Cookies + 1.8 foods_Corn_Flks,_Kellogg'S
#  + 0.3 foods_Couscous + 0.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 0.6 foods_Frankfurter,_Beef + 2.3 foods_Frozen_Broccoli
#  + 0.3 foods_Frozen_Corn + 0.1 foods_Grapes + 0.2 foods_Ham,Sliced,Extralean
#  + 2.5 foods_Hamburger_W_Toppings + 2.3 foods_Hotdog,_Plain
#  + 0.4 foods_Kielbasa,Prk + 0.3 foods_Kiwifruit,Raw,Fresh
#  + 0.1 foods_Lettuce,Iceberg,Raw + foods_Macaroni,Ckd
#  + 4.7 foods_Malt_O_Meal,Choc + 1.5 foods_New_E_Clamchwd,W_Mlk
#  + 2.8 foods_Neweng_Clamchwd + 1.6 foods_Oatmeal + 0.5 foods_Oatmeal_Cookies
#  + 0.1 foods_Oranges + 0.6 foods_Peanut_Butter + 0.3 foods_Peppers,_Sweet,_Raw
#  + 0.9 foods_Pizza_W_Pepperoni + 0.7 foods_Poached_Eggs
#  + 0.8 foods_Popcorn,Air_Popped + 0.4 foods_Pork
#  + 0.5 foods_Potato_Chips,Bbqflvr + 4.3 foods_Potatoes,_Baked
#  + 1.2 foods_Pretzels + 16.8 foods_Raisin_Brn,_Kellg'S
#  + 1.8 foods_Rice_Krispies + 1.8 foods_Roasted_Chicken
#  + 0.7 foods_Sardines_in_Oil + 0.7 foods_Scrambled_Eggs + 0.1 foods_Skim_Milk
#  + 2.3 foods_Spaghetti_W__Sauce + 4.5 foods_Special_K
#  + 2.1 foods_Splt_Pea&Hamsoup + 2.4 foods_Taco + 6.2 foods_Tofu
#  + 0.6 foods_Tomato,Red,Ripe,Raw + 3.5 foods_Tomato_Soup
#  + 0.4 foods_Tortilla_Chip + 2.2 foods_Vegetbeef_Soup + 0.7 foods_Wheat_Bread
#  + 0.8 foods_White_Bread + 0.9 foods_White_Rice
#  + 0.5 foods_White_Tuna_in_Water >= 10
#
# _C140: 121.2 foods_2%_Lowfat_Milk + 149.9 foods_3.3%_Fat,Whole_Milk
#  + 81.4 foods_Apple,Raw,W_Skin + 67.2 foods_Apple_Pie + 78 foods_Bagels
#  + 104.9 foods_Banana + 172 foods_Beanbacn_Soup,W_Watr
#  + 56.4 foods_Bologna,Turkey + 35.8 foods_Butter,Regular
#  + 119.6 foods_Cap'N_Crunch + 23.7 foods_Carrots,Raw + 6.4 foods_Celery,_Raw
#  + 112.7 foods_Cheddar_Cheese + 111 foods_Cheerios
#  + 150.1 foods_Chicknoodl_Soup + 78.1 foods_Chocolate_Chip_Cookies
#  + 110.5 foods_Corn_Flks,_Kellogg'S + 100.8 foods_Couscous
#  + 203.4 foods_Crm_Mshrm_Soup,W_Mlk + 141.8 foods_Frankfurter,_Beef
#  + 73.8 foods_Frozen_Broccoli + 72.2 foods_Frozen_Corn + 15.1 foods_Grapes
#  + 37.1 foods_Ham,Sliced,Extralean + 275 foods_Hamburger_W_Toppings
#  + 242.1 foods_Hotdog,_Plain + 80.6 foods_Kielbasa,Prk
#  + 46.4 foods_Kiwifruit,Raw,Fresh + 2.6 foods_Lettuce,Iceberg,Raw
#  + 98.7 foods_Macaroni,Ckd + 607.2 foods_Malt_O_Meal,Choc
#  + 163.7 foods_New_E_Clamchwd,W_Mlk + 175.7 foods_Neweng_Clamchwd
#  + 145.1 foods_Oatmeal + 81 foods_Oatmeal_Cookies + 61.6 foods_Oranges
#  + 188.5 foods_Peanut_Butter + 20 foods_Peppers,_Sweet,_Raw
#  + 181 foods_Pizza_W_Pepperoni + 74.5 foods_Poached_Eggs
#  + 108.3 foods_Popcorn,Air_Popped + 710.8 foods_Pork
#  + 139.2 foods_Potato_Chips,Bbqflvr + 171.5 foods_Potatoes,_Baked
#  + 108 foods_Pretzels + 115.1 foods_Raisin_Brn,_Kellg'S
#  + 112.2 foods_Rice_Krispies + 277.4 foods_Roasted_Chicken
#  + 49.9 foods_Sardines_in_Oil + 99.6 foods_Scrambled_Eggs
#  + 85.5 foods_Skim_Milk + 358.2 foods_Spaghetti_W__Sauce
#  + 110.8 foods_Special_K + 184.8 foods_Splt_Pea&Hamsoup + 369.4 foods_Taco
#  + 88.2 foods_Tofu + 25.8 foods_Tomato,Red,Ripe,Raw + 170.7 foods_Tomato_Soup
#  + 142 foods_Tortilla_Chip + 158.1 foods_Vegetbeef_Soup + 65 foods_Wheat_Bread
#  + 65 foods_White_Bread + 102.7 foods_White_Rice
#  + 115.6 foods_White_Tuna_in_Water <= 2500
#
# _C141: 18.3 foods_2%_Lowfat_Milk + 33.2 foods_3.3%_Fat,Whole_Milk
#  + 2.5 foods_Beanbacn_Soup,W_Watr + 28.1 foods_Bologna,Turkey
#  + 10.9 foods_Butter,Regular + 29.4 foods_Cheddar_Cheese
#  + 12.3 foods_Chicknoodl_Soup + 5.1 foods_Chocolate_Chip_Cookies
#  + 19.8 foods_Crm_Mshrm_Soup,W_Mlk + 27.4 foods_Frankfurter,_Beef
#  + 13.3 foods_Ham,Sliced,Extralean + 42.8 foods_Hamburger_W_Toppings
#  + 44.1 foods_Hotdog,_Plain + 17.4 foods_Kielbasa,Prk
#  + 22.3 foods_New_E_Clamchwd,W_Mlk + 10 foods_Neweng_Clamchwd
#  + 14.2 foods_Pizza_W_Pepperoni + 211.5 foods_Poached_Eggs + 105.1 foods_Pork
#  + 129.9 foods_Roasted_Chicken + 34.1 foods_Sardines_in_Oil
#  + 211.2 foods_Scrambled_Eggs + 4.4 foods_Skim_Milk
#  + 7.2 foods_Splt_Pea&Hamsoup + 56.4 foods_Taco + 10 foods_Vegetbeef_Soup
#  + 35.7 foods_White_Tuna_in_Water <= 240
#
# _C142: 4.7 foods_2%_Lowfat_Milk + 8.1 foods_3.3%_Fat,Whole_Milk
#  + 0.5 foods_Apple,Raw,W_Skin + 3.1 foods_Apple_Pie + 0.5 foods_Bagels
#  + 0.5 foods_Banana + 5.9 foods_Beanbacn_Soup,W_Watr
#  + 4.3 foods_Bologna,Turkey + 4.1 foods_Butter,Regular
#  + 2.6 foods_Cap'N_Crunch + 0.1 foods_Carrots,Raw + 0.1 foods_Celery,_Raw
#  + 9.3 foods_Cheddar_Cheese + 1.8 foods_Cheerios + 4.6 foods_Chicknoodl_Soup
#  + 4.5 foods_Chocolate_Chip_Cookies + 0.1 foods_Corn_Flks,_Kellogg'S
#  + 0.1 foods_Couscous + 13.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 12.8 foods_Frankfurter,_Beef + 0.8 foods_Frozen_Broccoli
#  + 0.6 foods_Frozen_Corn + 0.1 foods_Grapes + 1.4 foods_Ham,Sliced,Extralean
#  + 10.2 foods_Hamburger_W_Toppings + 14.5 foods_Hotdog,_Plain
#  + 7.1 foods_Kielbasa,Prk + 0.3 foods_Kiwifruit,Raw,Fresh
#  + 0.5 foods_Macaroni,Ckd + 1.5 foods_Malt_O_Meal,Choc
#  + 6.6 foods_New_E_Clamchwd,W_Mlk + 5 foods_Neweng_Clamchwd
#  + 2.3 foods_Oatmeal + 3.3 foods_Oatmeal_Cookies + 0.2 foods_Oranges
#  + 16 foods_Peanut_Butter + 0.1 foods_Peppers,_Sweet,_Raw
#  + 7 foods_Pizza_W_Pepperoni + 5 foods_Poached_Eggs
#  + 1.2 foods_Popcorn,Air_Popped + 72.2 foods_Pork
#  + 9.2 foods_Potato_Chips,Bbqflvr + 0.2 foods_Potatoes,_Baked + foods_Pretzels
#  + 0.7 foods_Raisin_Brn,_Kellg'S + 0.2 foods_Rice_Krispies
#  + 10.8 foods_Roasted_Chicken + 2.7 foods_Sardines_in_Oil
#  + 7.3 foods_Scrambled_Eggs + 0.4 foods_Skim_Milk
#  + 12.3 foods_Spaghetti_W__Sauce + 0.1 foods_Special_K
#  + 4 foods_Splt_Pea&Hamsoup + 20.6 foods_Taco + 5.5 foods_Tofu
#  + 0.4 foods_Tomato,Red,Ripe,Raw + 3.8 foods_Tomato_Soup
#  + 7.4 foods_Tortilla_Chip + 3.8 foods_Vegetbeef_Soup + foods_Wheat_Bread
#  + foods_White_Bread + 0.2 foods_White_Rice + 2.1 foods_White_Tuna_in_Water
#  <= 70
#
# _C143: 121.8 foods_2%_Lowfat_Milk + 119.6 foods_3.3%_Fat,Whole_Milk
#  + 75.4 foods_Apple_Pie + 151.4 foods_Bagels + 1.1 foods_Banana
#  + 951.3 foods_Beanbacn_Soup,W_Watr + 248.9 foods_Bologna,Turkey
#  + 41.3 foods_Butter,Regular + 213.3 foods_Cap'N_Crunch
#  + 19.2 foods_Carrots,Raw + 34.8 foods_Celery,_Raw
#  + 173.7 foods_Cheddar_Cheese + 307.6 foods_Cheerios
#  + 1862.2 foods_Chicknoodl_Soup + 57.8 foods_Chocolate_Chip_Cookies
#  + 290.5 foods_Corn_Flks,_Kellogg'S + 4.5 foods_Couscous
#  + 1076.3 foods_Crm_Mshrm_Soup,W_Mlk + 461.7 foods_Frankfurter,_Beef
#  + 68.2 foods_Frozen_Broccoli + 2.5 foods_Frozen_Corn + 0.5 foods_Grapes
#  + 405.1 foods_Ham,Sliced,Extralean + 563.9 foods_Hamburger_W_Toppings
#  + 670.3 foods_Hotdog,_Plain + 279.8 foods_Kielbasa,Prk
#  + 3.8 foods_Kiwifruit,Raw,Fresh + 1.8 foods_Lettuce,Iceberg,Raw
#  + 0.7 foods_Macaroni,Ckd + 16.5 foods_Malt_O_Meal,Choc
#  + 992 foods_New_E_Clamchwd,W_Mlk + 1864.9 foods_Neweng_Clamchwd
#  + 2.3 foods_Oatmeal + 68.9 foods_Oatmeal_Cookies + 155.5 foods_Peanut_Butter
#  + 1.5 foods_Peppers,_Sweet,_Raw + 267 foods_Pizza_W_Pepperoni
#  + 140 foods_Poached_Eggs + 1.1 foods_Popcorn,Air_Popped + 38.4 foods_Pork
#  + 212.6 foods_Potato_Chips,Bbqflvr + 15.2 foods_Potatoes,_Baked
#  + 486.2 foods_Pretzels + 204.4 foods_Raisin_Brn,_Kellg'S
#  + 340.8 foods_Rice_Krispies + 125.6 foods_Roasted_Chicken
#  + 121.2 foods_Sardines_in_Oil + 168 foods_Scrambled_Eggs
#  + 126.2 foods_Skim_Milk + 1237.1 foods_Spaghetti_W__Sauce
#  + 265.5 foods_Special_K + 964.8 foods_Splt_Pea&Hamsoup + 802 foods_Taco
#  + 8.1 foods_Tofu + 11.1 foods_Tomato,Red,Ripe,Raw + 1744.4 foods_Tomato_Soup
#  + 149.7 foods_Tortilla_Chip + 1915.1 foods_Vegetbeef_Soup
#  + 134.5 foods_Wheat_Bread + 132.5 foods_White_Bread + 0.8 foods_White_Rice
#  + 333.2 foods_White_Tuna_in_Water <= 2000
#
# _C144: 11.7 foods_2%_Lowfat_Milk + 11.4 foods_3.3%_Fat,Whole_Milk
#  + 21 foods_Apple,Raw,W_Skin + 9.6 foods_Apple_Pie + 15.1 foods_Bagels
#  + 26.7 foods_Banana + 22.8 foods_Beanbacn_Soup,W_Watr
#  + 0.3 foods_Bologna,Turkey + 23 foods_Cap'N_Crunch + 5.6 foods_Carrots,Raw
#  + 1.5 foods_Celery,_Raw + 0.4 foods_Cheddar_Cheese + 19.6 foods_Cheerios
#  + 18.7 foods_Chicknoodl_Soup + 9.3 foods_Chocolate_Chip_Cookies
#  + 24.5 foods_Corn_Flks,_Kellogg'S + 20.9 foods_Couscous
#  + 15 foods_Crm_Mshrm_Soup,W_Mlk + 0.8 foods_Frankfurter,_Beef
#  + 13.6 foods_Frozen_Broccoli + 17.1 foods_Frozen_Corn + 4.1 foods_Grapes
#  + 0.3 foods_Ham,Sliced,Extralean + 32.7 foods_Hamburger_W_Toppings
#  + 18 foods_Hotdog,_Plain + 0.6 foods_Kielbasa,Prk
#  + 11.3 foods_Kiwifruit,Raw,Fresh + 0.4 foods_Lettuce,Iceberg,Raw
#  + 19.8 foods_Macaroni,Ckd + 128.2 foods_Malt_O_Meal,Choc
#  + 16.6 foods_New_E_Clamchwd,W_Mlk + 21.8 foods_Neweng_Clamchwd
#  + 25.3 foods_Oatmeal + 12.4 foods_Oatmeal_Cookies + 15.4 foods_Oranges
#  + 6.9 foods_Peanut_Butter + 4.8 foods_Peppers,_Sweet,_Raw
#  + 19.9 foods_Pizza_W_Pepperoni + 0.6 foods_Poached_Eggs
#  + 22.1 foods_Popcorn,Air_Popped + 15 foods_Potato_Chips,Bbqflvr
#  + 39.9 foods_Potatoes,_Baked + 22.5 foods_Pretzels
#  + 27.9 foods_Raisin_Brn,_Kellg'S + 24.8 foods_Rice_Krispies
#  + 1.3 foods_Scrambled_Eggs + 11.9 foods_Skim_Milk
#  + 58.3 foods_Spaghetti_W__Sauce + 21.3 foods_Special_K
#  + 26.8 foods_Splt_Pea&Hamsoup + 26.7 foods_Taco + 2.2 foods_Tofu
#  + 5.7 foods_Tomato,Red,Ripe,Raw + 33.2 foods_Tomato_Soup
#  + 17.8 foods_Tortilla_Chip + 20.4 foods_Vegetbeef_Soup
#  + 12.4 foods_Wheat_Bread + 11.8 foods_White_Bread + 22.3 foods_White_Rice
#  <= 450
#
# _C145: 3.7 foods_Apple,Raw,W_Skin + 0.5 foods_Apple_Pie + 0.6 foods_Bagels
#  + 2.7 foods_Banana + 8.6 foods_Beanbacn_Soup,W_Watr + 0.5 foods_Cap'N_Crunch
#  + 1.6 foods_Carrots,Raw + 0.7 foods_Celery,_Raw + 2 foods_Cheerios
#  + 1.5 foods_Chicknoodl_Soup + 0.7 foods_Corn_Flks,_Kellogg'S
#  + 1.3 foods_Couscous + 0.5 foods_Crm_Mshrm_Soup,W_Mlk
#  + 8.5 foods_Frozen_Broccoli + 2 foods_Frozen_Corn + 0.2 foods_Grapes
#  + 2.6 foods_Kiwifruit,Raw,Fresh + 0.3 foods_Lettuce,Iceberg,Raw
#  + 0.9 foods_Macaroni,Ckd + 1.5 foods_New_E_Clamchwd,W_Mlk
#  + 1.5 foods_Neweng_Clamchwd + 4 foods_Oatmeal + 0.6 foods_Oatmeal_Cookies
#  + 3.1 foods_Oranges + 2.1 foods_Peanut_Butter + 1.3 foods_Peppers,_Sweet,_Raw
#  + 4.3 foods_Popcorn,Air_Popped + 1.2 foods_Potato_Chips,Bbqflvr
#  + 3.2 foods_Potatoes,_Baked + 0.9 foods_Pretzels
#  + 4 foods_Raisin_Brn,_Kellg'S + 0.4 foods_Rice_Krispies
#  + 11.6 foods_Spaghetti_W__Sauce + 0.7 foods_Special_K
#  + 4.1 foods_Splt_Pea&Hamsoup + 1.4 foods_Tofu + 1.4 foods_Tomato,Red,Ripe,Raw
#  + foods_Tomato_Soup + 1.8 foods_Tortilla_Chip + 4 foods_Vegetbeef_Soup
#  + 1.3 foods_Wheat_Bread + 1.1 foods_White_Bread + 0.3 foods_White_Rice <= 250
#
# _C146: 8.1 foods_2%_Lowfat_Milk + 8 foods_3.3%_Fat,Whole_Milk
#  + 0.3 foods_Apple,Raw,W_Skin + 0.5 foods_Apple_Pie + 3 foods_Bagels
#  + 1.2 foods_Banana + 7.9 foods_Beanbacn_Soup,W_Watr
#  + 3.9 foods_Bologna,Turkey + 1.4 foods_Cap'N_Crunch + 0.6 foods_Carrots,Raw
#  + 0.3 foods_Celery,_Raw + 7 foods_Cheddar_Cheese + 4.3 foods_Cheerios
#  + 7.9 foods_Chicknoodl_Soup + 0.9 foods_Chocolate_Chip_Cookies
#  + 2.3 foods_Corn_Flks,_Kellogg'S + 3.4 foods_Couscous
#  + 6.1 foods_Crm_Mshrm_Soup,W_Mlk + 5.4 foods_Frankfurter,_Beef
#  + 8 foods_Frozen_Broccoli + 2.5 foods_Frozen_Corn + 0.2 foods_Grapes
#  + 5.5 foods_Ham,Sliced,Extralean + 13.6 foods_Hamburger_W_Toppings
#  + 10.4 foods_Hotdog,_Plain + 3.4 foods_Kielbasa,Prk
#  + 0.8 foods_Kiwifruit,Raw,Fresh + 0.2 foods_Lettuce,Iceberg,Raw
#  + 3.3 foods_Macaroni,Ckd + 17.3 foods_Malt_O_Meal,Choc
#  + 9.5 foods_New_E_Clamchwd,W_Mlk + 10.9 foods_Neweng_Clamchwd
#  + 6.1 foods_Oatmeal + 1.1 foods_Oatmeal_Cookies + 1.2 foods_Oranges
#  + 7.7 foods_Peanut_Butter + 0.7 foods_Peppers,_Sweet,_Raw
#  + 10.1 foods_Pizza_W_Pepperoni + 6.2 foods_Poached_Eggs
#  + 3.4 foods_Popcorn,Air_Popped + 13.8 foods_Pork
#  + 2.2 foods_Potato_Chips,Bbqflvr + 3.7 foods_Potatoes,_Baked
#  + 2.6 foods_Pretzels + 4 foods_Raisin_Brn,_Kellg'S + 1.9 foods_Rice_Krispies
#  + 42.2 foods_Roasted_Chicken + 5.9 foods_Sardines_in_Oil
#  + 6.7 foods_Scrambled_Eggs + 8.4 foods_Skim_Milk
#  + 8.2 foods_Spaghetti_W__Sauce + 5.6 foods_Special_K
#  + 11.1 foods_Splt_Pea&Hamsoup + 20.7 foods_Taco + 9.4 foods_Tofu
#  + foods_Tomato,Red,Ripe,Raw + 4.1 foods_Tomato_Soup + 2 foods_Tortilla_Chip
#  + 11.2 foods_Vegetbeef_Soup + 2.2 foods_Wheat_Bread + 2.3 foods_White_Bread
#  + 2.1 foods_White_Rice + 22.7 foods_White_Tuna_in_Water <= 100
#
# _C147: 500.2 foods_2%_Lowfat_Milk + 307.4 foods_3.3%_Fat,Whole_Milk
#  + 73.1 foods_Apple,Raw,W_Skin + 35.2 foods_Apple_Pie + 92.3 foods_Banana
#  + 888 foods_Beanbacn_Soup,W_Watr + 152.9 foods_Butter,Regular
#  + 40.6 foods_Cap'N_Crunch + 15471 foods_Carrots,Raw + 53.6 foods_Celery,_Raw
#  + 296.5 foods_Cheddar_Cheese + 1252.2 foods_Cheerios
#  + 1308.7 foods_Chicknoodl_Soup + 101.8 foods_Chocolate_Chip_Cookies
#  + 1252.2 foods_Corn_Flks,_Kellogg'S + 153.8 foods_Crm_Mshrm_Soup,W_Mlk
#  + 5867.4 foods_Frozen_Broccoli + 106.6 foods_Frozen_Corn + 24 foods_Grapes
#  + 126.3 foods_Hamburger_W_Toppings + 133 foods_Kiwifruit,Raw,Fresh
#  + 66 foods_Lettuce,Iceberg,Raw + 163.7 foods_New_E_Clamchwd,W_Mlk
#  + 20.1 foods_Neweng_Clamchwd + 37.4 foods_Oatmeal + 2.9 foods_Oatmeal_Cookies
#  + 268.6 foods_Oranges + 467.7 foods_Peppers,_Sweet,_Raw
#  + 281.9 foods_Pizza_W_Pepperoni + 316 foods_Poached_Eggs
#  + 55.6 foods_Popcorn,Air_Popped + 14.7 foods_Pork
#  + 61.5 foods_Potato_Chips,Bbqflvr + 1250.2 foods_Raisin_Brn,_Kellg'S
#  + 1252.2 foods_Rice_Krispies + 77.4 foods_Roasted_Chicken
#  + 53.8 foods_Sardines_in_Oil + 409.2 foods_Scrambled_Eggs
#  + 499.8 foods_Skim_Milk + 3055.2 foods_Spaghetti_W__Sauce
#  + 1252.2 foods_Special_K + 4872 foods_Splt_Pea&Hamsoup + 855 foods_Taco
#  + 98.6 foods_Tofu + 766.3 foods_Tomato,Red,Ripe,Raw + 1393 foods_Tomato_Soup
#  + 55.6 foods_Tortilla_Chip + 3785.1 foods_Vegetbeef_Soup
#  + 68 foods_White_Tuna_in_Water <= 10000
#
# _C148: 2.3 foods_2%_Lowfat_Milk + 2.3 foods_3.3%_Fat,Whole_Milk
#  + 7.9 foods_Apple,Raw,W_Skin + 0.9 foods_Apple_Pie + 10.4 foods_Banana
#  + 1.5 foods_Beanbacn_Soup,W_Watr + 5.1 foods_Carrots,Raw
#  + 2.8 foods_Celery,_Raw + 15.1 foods_Cheerios
#  + 15.1 foods_Corn_Flks,_Kellogg'S + 2.2 foods_Crm_Mshrm_Soup,W_Mlk
#  + 10.8 foods_Frankfurter,_Beef + 160.2 foods_Frozen_Broccoli
#  + 5.2 foods_Frozen_Corn + foods_Grapes + 7.4 foods_Ham,Sliced,Extralean
#  + 2.6 foods_Hamburger_W_Toppings + 0.1 foods_Hotdog,_Plain
#  + 5.5 foods_Kielbasa,Prk + 74.5 foods_Kiwifruit,Raw,Fresh
#  + 0.8 foods_Lettuce,Iceberg,Raw + 3.5 foods_New_E_Clamchwd,W_Mlk
#  + 4.8 foods_Neweng_Clamchwd + 0.1 foods_Oatmeal_Cookies + 69.7 foods_Oranges
#  + 66.1 foods_Peppers,_Sweet,_Raw + 1.6 foods_Pizza_W_Pepperoni
#  + 9.6 foods_Potato_Chips,Bbqflvr + 15.6 foods_Potatoes,_Baked
#  + 15.1 foods_Rice_Krispies + 0.1 foods_Scrambled_Eggs + 2.4 foods_Skim_Milk
#  + 27.9 foods_Spaghetti_W__Sauce + 15.1 foods_Special_K
#  + 7 foods_Splt_Pea&Hamsoup + 2.2 foods_Taco + 0.1 foods_Tofu
#  + 23.5 foods_Tomato,Red,Ripe,Raw + 133 foods_Tomato_Soup
#  + 4.8 foods_Vegetbeef_Soup <= 5000
#
# _C149: 296.7 foods_2%_Lowfat_Milk + 291.3 foods_3.3%_Fat,Whole_Milk
#  + 9.7 foods_Apple,Raw,W_Skin + 3.1 foods_Apple_Pie + 21 foods_Bagels
#  + 6.8 foods_Banana + 81 foods_Beanbacn_Soup,W_Watr
#  + 23.8 foods_Bologna,Turkey + 1.2 foods_Butter,Regular
#  + 4.8 foods_Cap'N_Crunch + 14.9 foods_Carrots,Raw + 16 foods_Celery,_Raw
#  + 202 foods_Cheddar_Cheese + 48.6 foods_Cheerios + 27.1 foods_Chicknoodl_Soup
#  + 6.2 foods_Chocolate_Chip_Cookies + 0.9 foods_Corn_Flks,_Kellogg'S
#  + 7.2 foods_Couscous + 178.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 9 foods_Frankfurter,_Beef + 159 foods_Frozen_Broccoli
#  + 3.3 foods_Frozen_Corn + 3.4 foods_Grapes + 2 foods_Ham,Sliced,Extralean
#  + 51.4 foods_Hamburger_W_Toppings + 23.5 foods_Hotdog,_Plain
#  + 11.4 foods_Kielbasa,Prk + 19.8 foods_Kiwifruit,Raw,Fresh
#  + 3.8 foods_Lettuce,Iceberg,Raw + 4.9 foods_Macaroni,Ckd
#  + 23.1 foods_Malt_O_Meal,Choc + 186 foods_New_E_Clamchwd,W_Mlk
#  + 82.8 foods_Neweng_Clamchwd + 18.7 foods_Oatmeal + 6.7 foods_Oatmeal_Cookies
#  + 52.4 foods_Oranges + 13.1 foods_Peanut_Butter
#  + 6.7 foods_Peppers,_Sweet,_Raw + 64.6 foods_Pizza_W_Pepperoni
#  + 24.5 foods_Poached_Eggs + 2.8 foods_Popcorn,Air_Popped + 59.9 foods_Pork
#  + 14.2 foods_Potato_Chips,Bbqflvr + 22.7 foods_Potatoes,_Baked
#  + 10.2 foods_Pretzels + 12.9 foods_Raisin_Brn,_Kellg'S
#  + 4 foods_Rice_Krispies + 21.9 foods_Roasted_Chicken
#  + 91.7 foods_Sardines_in_Oil + 42.6 foods_Scrambled_Eggs
#  + 302.3 foods_Skim_Milk + 80.2 foods_Spaghetti_W__Sauce + 8.2 foods_Special_K
#  + 33.6 foods_Splt_Pea&Hamsoup + 220.6 foods_Taco + 121.8 foods_Tofu
#  + 6.2 foods_Tomato,Red,Ripe,Raw + 27.6 foods_Tomato_Soup
#  + 43.7 foods_Tortilla_Chip + 32.6 foods_Vegetbeef_Soup
#  + 10.8 foods_Wheat_Bread + 26.2 foods_White_Bread + 7.9 foods_White_Rice
#  + 3.4 foods_White_Tuna_in_Water <= 1500
#
# _C150: 0.1 foods_2%_Lowfat_Milk + 0.1 foods_3.3%_Fat,Whole_Milk
#  + 0.2 foods_Apple,Raw,W_Skin + 0.1 foods_Apple_Pie + foods_Bagels
#  + 0.4 foods_Banana + 2 foods_Beanbacn_Soup,W_Watr + 0.4 foods_Bologna,Turkey
#  + 7.5 foods_Cap'N_Crunch + 0.3 foods_Carrots,Raw + 0.2 foods_Celery,_Raw
#  + 0.2 foods_Cheddar_Cheese + 4.5 foods_Cheerios + 1.5 foods_Chicknoodl_Soup
#  + 0.4 foods_Chocolate_Chip_Cookies + 1.8 foods_Corn_Flks,_Kellogg'S
#  + 0.3 foods_Couscous + 0.6 foods_Crm_Mshrm_Soup,W_Mlk
#  + 0.6 foods_Frankfurter,_Beef + 2.3 foods_Frozen_Broccoli
#  + 0.3 foods_Frozen_Corn + 0.1 foods_Grapes + 0.2 foods_Ham,Sliced,Extralean
#  + 2.5 foods_Hamburger_W_Toppings + 2.3 foods_Hotdog,_Plain
#  + 0.4 foods_Kielbasa,Prk + 0.3 foods_Kiwifruit,Raw,Fresh
#  + 0.1 foods_Lettuce,Iceberg,Raw + foods_Macaroni,Ckd
#  + 4.7 foods_Malt_O_Meal,Choc + 1.5 foods_New_E_Clamchwd,W_Mlk
#  + 2.8 foods_Neweng_Clamchwd + 1.6 foods_Oatmeal + 0.5 foods_Oatmeal_Cookies
#  + 0.1 foods_Oranges + 0.6 foods_Peanut_Butter + 0.3 foods_Peppers,_Sweet,_Raw
#  + 0.9 foods_Pizza_W_Pepperoni + 0.7 foods_Poached_Eggs
#  + 0.8 foods_Popcorn,Air_Popped + 0.4 foods_Pork
#  + 0.5 foods_Potato_Chips,Bbqflvr + 4.3 foods_Potatoes,_Baked
#  + 1.2 foods_Pretzels + 16.8 foods_Raisin_Brn,_Kellg'S
#  + 1.8 foods_Rice_Krispies + 1.8 foods_Roasted_Chicken
#  + 0.7 foods_Sardines_in_Oil + 0.7 foods_Scrambled_Eggs + 0.1 foods_Skim_Milk
#  + 2.3 foods_Spaghetti_W__Sauce + 4.5 foods_Special_K
#  + 2.1 foods_Splt_Pea&Hamsoup + 2.4 foods_Taco + 6.2 foods_Tofu
#  + 0.6 foods_Tomato,Red,Ripe,Raw + 3.5 foods_Tomato_Soup
#  + 0.4 foods_Tortilla_Chip + 2.2 foods_Vegetbeef_Soup + 0.7 foods_Wheat_Bread
#  + 0.8 foods_White_Bread + 0.9 foods_White_Rice
#  + 0.5 foods_White_Tuna_in_Water <= 40
#
# _C151: chosen_Celery,_Raw + chosen_Frozen_Broccoli <= 1
#
# _C152: chosen_Bologna,Turkey + chosen_Frankfurter,_Beef
#  + chosen_Ham,Sliced,Extralean + chosen_Hamburger_W_Toppings
#  + chosen_Hotdog,_Plain + chosen_Kielbasa,Prk + chosen_Poached_Eggs
#  + chosen_Pork + chosen_Roasted_Chicken + chosen_Sardines_in_Oil
#  + chosen_Scrambled_Eggs + chosen_White_Tuna_in_Water >= 3
#
# VARIABLES
# 0 <= chosen_2%_Lowfat_Milk <= 1 Integer
# 0 <= chosen_3.3%_Fat,Whole_Milk <= 1 Integer
# 0 <= chosen_Apple,Raw,W_Skin <= 1 Integer
# 0 <= chosen_Apple_Pie <= 1 Integer
# 0 <= chosen_Bagels <= 1 Integer
# 0 <= chosen_Banana <= 1 Integer
# 0 <= chosen_Beanbacn_Soup,W_Watr <= 1 Integer
# 0 <= chosen_Bologna,Turkey <= 1 Integer
# 0 <= chosen_Butter,Regular <= 1 Integer
# 0 <= chosen_Cap'N_Crunch <= 1 Integer
# 0 <= chosen_Carrots,Raw <= 1 Integer
# 0 <= chosen_Celery,_Raw <= 1 Integer
# 0 <= chosen_Cheddar_Cheese <= 1 Integer
# 0 <= chosen_Cheerios <= 1 Integer
# 0 <= chosen_Chicknoodl_Soup <= 1 Integer
# 0 <= chosen_Chocolate_Chip_Cookies <= 1 Integer
# 0 <= chosen_Corn_Flks,_Kellogg'S <= 1 Integer
# 0 <= chosen_Couscous <= 1 Integer
# 0 <= chosen_Crm_Mshrm_Soup,W_Mlk <= 1 Integer
# 0 <= chosen_Frankfurter,_Beef <= 1 Integer
# 0 <= chosen_Frozen_Broccoli <= 1 Integer
# 0 <= chosen_Frozen_Corn <= 1 Integer
# 0 <= chosen_Grapes <= 1 Integer
# 0 <= chosen_Ham,Sliced,Extralean <= 1 Integer
# 0 <= chosen_Hamburger_W_Toppings <= 1 Integer
# 0 <= chosen_Hotdog,_Plain <= 1 Integer
# 0 <= chosen_Kielbasa,Prk <= 1 Integer
# 0 <= chosen_Kiwifruit,Raw,Fresh <= 1 Integer
# 0 <= chosen_Lettuce,Iceberg,Raw <= 1 Integer
# 0 <= chosen_Macaroni,Ckd <= 1 Integer
# 0 <= chosen_Malt_O_Meal,Choc <= 1 Integer
# 0 <= chosen_New_E_Clamchwd,W_Mlk <= 1 Integer
# 0 <= chosen_Neweng_Clamchwd <= 1 Integer
# 0 <= chosen_Oatmeal <= 1 Integer
# 0 <= chosen_Oatmeal_Cookies <= 1 Integer
# 0 <= chosen_Oranges <= 1 Integer
# 0 <= chosen_Peanut_Butter <= 1 Integer
# 0 <= chosen_Peppers,_Sweet,_Raw <= 1 Integer
# 0 <= chosen_Pizza_W_Pepperoni <= 1 Integer
# 0 <= chosen_Poached_Eggs <= 1 Integer
# 0 <= chosen_Popcorn,Air_Popped <= 1 Integer
# 0 <= chosen_Pork <= 1 Integer
# 0 <= chosen_Potato_Chips,Bbqflvr <= 1 Integer
# 0 <= chosen_Potatoes,_Baked <= 1 Integer
# 0 <= chosen_Pretzels <= 1 Integer
# 0 <= chosen_Raisin_Brn,_Kellg'S <= 1 Integer
# 0 <= chosen_Rice_Krispies <= 1 Integer
# 0 <= chosen_Roasted_Chicken <= 1 Integer
# 0 <= chosen_Sardines_in_Oil <= 1 Integer
# 0 <= chosen_Scrambled_Eggs <= 1 Integer
# 0 <= chosen_Skim_Milk <= 1 Integer
# 0 <= chosen_Spaghetti_W__Sauce <= 1 Integer
# 0 <= chosen_Special_K <= 1 Integer
# 0 <= chosen_Splt_Pea&Hamsoup <= 1 Integer
# 0 <= chosen_Taco <= 1 Integer
# 0 <= chosen_Tofu <= 1 Integer
# 0 <= chosen_Tomato,Red,Ripe,Raw <= 1 Integer
# 0 <= chosen_Tomato_Soup <= 1 Integer
# 0 <= chosen_Tortilla_Chip <= 1 Integer
# 0 <= chosen_Vegetbeef_Soup <= 1 Integer
# 0 <= chosen_Wheat_Bread <= 1 Integer
# 0 <= chosen_White_Bread <= 1 Integer
# 0 <= chosen_White_Rice <= 1 Integer
# 0 <= chosen_White_Tuna_in_Water <= 1 Integer
# foods_2%_Lowfat_Milk Continuous
# foods_3.3%_Fat,Whole_Milk Continuous
# foods_Apple,Raw,W_Skin Continuous
# foods_Apple_Pie Continuous
# foods_Bagels Continuous
# foods_Banana Continuous
# foods_Beanbacn_Soup,W_Watr Continuous
# foods_Bologna,Turkey Continuous
# foods_Butter,Regular Continuous
# foods_Cap'N_Crunch Continuous
# foods_Carrots,Raw Continuous
# foods_Celery,_Raw Continuous
# foods_Cheddar_Cheese Continuous
# foods_Cheerios Continuous
# foods_Chicknoodl_Soup Continuous
# foods_Chocolate_Chip_Cookies Continuous
# foods_Corn_Flks,_Kellogg'S Continuous
# foods_Couscous Continuous
# foods_Crm_Mshrm_Soup,W_Mlk Continuous
# foods_Frankfurter,_Beef Continuous
# foods_Frozen_Broccoli Continuous
# foods_Frozen_Corn Continuous
# foods_Grapes Continuous
# foods_Ham,Sliced,Extralean Continuous
# foods_Hamburger_W_Toppings Continuous
# foods_Hotdog,_Plain Continuous
# foods_Kielbasa,Prk Continuous
# foods_Kiwifruit,Raw,Fresh Continuous
# foods_Lettuce,Iceberg,Raw Continuous
# foods_Macaroni,Ckd Continuous
# foods_Malt_O_Meal,Choc Continuous
# foods_New_E_Clamchwd,W_Mlk Continuous
# foods_Neweng_Clamchwd Continuous
# foods_Oatmeal Continuous
# foods_Oatmeal_Cookies Continuous
# foods_Oranges Continuous
# foods_Peanut_Butter Continuous
# foods_Peppers,_Sweet,_Raw Continuous
# foods_Pizza_W_Pepperoni Continuous
# foods_Poached_Eggs Continuous
# foods_Popcorn,Air_Popped Continuous
# foods_Pork Continuous
# foods_Potato_Chips,Bbqflvr Continuous
# foods_Potatoes,_Baked Continuous
# foods_Pretzels Continuous
# foods_Raisin_Brn,_Kellg'S Continuous
# foods_Rice_Krispies Continuous
# foods_Roasted_Chicken Continuous
# foods_Sardines_in_Oil Continuous
# foods_Scrambled_Eggs Continuous
# foods_Skim_Milk Continuous
# foods_Spaghetti_W__Sauce Continuous
# foods_Special_K Continuous
# foods_Splt_Pea&Hamsoup Continuous
# foods_Taco Continuous
# foods_Tofu Continuous
# foods_Tomato,Red,Ripe,Raw Continuous
# foods_Tomato_Soup Continuous
# foods_Tortilla_Chip Continuous
# foods_Vegetbeef_Soup Continuous
# foods_Wheat_Bread Continuous
# foods_White_Bread Continuous
# foods_White_Rice Continuous
# foods_White_Tuna_in_Water Continuous

# %%
model2.solve()
# Out:
# 1

# %%
print('Optimization Solution:')

for v in model2.variables():
    if v.varValue > 0:
        if str(v).find('Chosen'):
            print(str(v.varValue) + " units of " + str(v))
# Out:
# Optimization Solution:
# 1.0 units of chosen_Celery,_Raw
# 1.0 units of chosen_Kielbasa,Prk
# 1.0 units of chosen_Lettuce,Iceberg,Raw
# 1.0 units of chosen_Oranges
# 1.0 units of chosen_Peanut_Butter
# 1.0 units of chosen_Poached_Eggs
# 1.0 units of chosen_Popcorn,Air_Popped
# 1.0 units of chosen_Scrambled_Eggs
# 42.399358 units of foods_Celery,_Raw
# 0.1 units of foods_Kielbasa,Prk
# 82.802586 units of foods_Lettuce,Iceberg,Raw
# 3.0771841 units of foods_Oranges
# 1.9429716 units of foods_Peanut_Butter
# 0.1 units of foods_Poached_Eggs
# 13.223294 units of foods_Popcorn,Air_Popped
# 0.1 units of foods_Scrambled_Eggs

# %%
print("Total cost of food = $%.2f" % value(model2.objective))
# Out:
# Total cost of food = $4.51
